# %% [markdown]
# ![title](./pic/aditional_functions/replace_split/1_title.png)

# %%
import pandas as pd
from tqdm.notebook import tqdm, trange

# %%
cars = pd.DataFrame({'marke': ['Bmw', 
                               'Audi', 
                               'Mercedes'
                                ], 
                    'preis': ['19.999 €', 
                              '12.456 €', 
                              '23.189 €'
                             ]
                    })

# %% [markdown]
# Meist kommen die Daten nicht in dem Format an, in dem wir sie brauchen könnnen. So zum Beispiel auch Preise von gecrawlten Webseiten. In diesem Beispiel kümmern wir uns Darum, wie wir einzelne Daten bereitigen können. Hierzu zählt das entfernen von etwaigen Trennzeichen und das aufsplitten von Strings um letzten Endes eine für uns vorteilhafte Darstellung der Daten zu erlangen.

# %% [markdown]
# ---

# %%
cars['preis']
# Out:
# 0    19.999 €
# 1    12.456 €
# 2    23.189 €
# Name: preis, dtype: object

# %%
type(cars.loc[0, 'preis'])
# Out:
# str

# %% [markdown]
# <br>
#
# Die `.replace`-Methode in `Pandas` ermöglicht es dir, die Werte in einer bestimmten `Series` in deinem `DataFrame` nach einem Wert oder einer Teilzeichenkette zu durchsuchen, die du dann ändern kannst.

# %% [markdown]
# ![title](./pic/aditional_functions/replace_split/2_replace.png)

# %%
cars.loc[0, 'preis']
# Out:
# '19.999 €'

# %% [markdown]
# Mit der `.replace()`-Methode, können wir einzelne (oder auch mehrere) Chars ersetzten oder gar ganz entfernen. So auch in diesem Beispiel, wobei hier ein Tausend-Trennpunkt eingefügt ist. Für Kalkulationen ist diese Art der Trennung schlecht, da es sich hierbei um einen `String` und nicht um einen `int` oder `float` Wert handelt. Daher ersetzten wir den `.` mit nichts.

# %%
cars.loc[0, 'preis'].replace('.', '')
# Out:
# '19999 €'

# %% [markdown]
# Nachdem die Überprüfung erfolgreich war, können wir diese Methode auf das komplette `DataFrame` anwenden.

# %%
cars["preis"] = cars["preis"].str.replace('.', '')
# Out:
# /Applications/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
#   """Entry point for launching an IPython kernel.

# %%
cars
# Out:
#       marke    preis
# 0       Bmw  19999 €
# 1      Audi  12456 €
# 2  Mercedes  23189 €

# %% [markdown]
# <br>
#
# Die Python-Methode `.split()` unterteilt einen `String` in eine `list`. Die Werte in der resultierenden Liste werden anhand eines Trennzeichens getrennt. Das Trennzeichen ist standardmäßig ein Leerzeichen. Übliche Trennzeichen sind **Leerzeichen** und **Kommas**.

# %% [markdown]
# ![title](./pic/aditional_functions/replace_split/3_split.png)

# %% [markdown]
# Als nächstes können wir die Methode `.split()` verwenden. Dieser Methode übergeben wir einen `Char`, andem ein `String` aufgespalten werden soll. Resultierend daraus erhalten wir eine `list` zurück, die die jeweils getrennten Elemente beinhaltet.

# %%
cars.loc[0, 'preis']
# Out:
# '19999 €'

# %%
cars.loc[0, 'preis'].split(' ')
# Out:
# ['19999', '€']

# %% [markdown]
# Abschließend können wir mit dem einfach `[]`-Operator, auf das von uns gewünschte Element zugreifen und erhalten dadurch genau die Zahl, die wir für weitere Analyse benötigen.

# %%
cars.loc[0, 'preis'].split(' ')[0]
# Out:
# '19999'

# %%
for i in trange(len(cars)):
    cars.loc[i, 'preis'] = cars.loc[i, 'preis'].split(' ')[0]
# Out:
#   0%|          | 0/3 [00:00<?, ?it/s]

# %%
cars
# Out:
#       marke  preis
# 0       Bmw  19999
# 1      Audi  12456
# 2  Mercedes  23189

# %% [markdown]
# ---

# %% [markdown]
# ## Real-Word Dataset: Cars Datensatz Feature `Preis` Preprocessing

# %%
df = pd.read_csv('./csv/replace_split/cars.csv', index_col=0)
df.head()
# Out:
#            marke   modell     preis   kilometer erstzulassung  \
# 0     Volkswagen     Golf   9.797 €   79.449 km       04/2011
# 1     Volkswagen     Golf  13.890 €   76.486 km       01/2015
# 2  Mercedes-Benz  SLK 300  19.990 €   84.000 km       07/2009
# 3  Mercedes-Benz  SLK 350  19.990 €   84.000 km       07/2009
# 4  Mercedes-Benz    A 220  17.450 €  109.252 km       12/2012
#
#           kraftstoffart        getriebe         leistung    hubraum       hu  \
# 0                Benzin  Schaltgetriebe    63 kW (86 PS)  1.197 cm³      Neu
# 1  Benzin, E10-geeignet  Schaltgetriebe   92 kW (125 PS)  1.395 cm³      Neu
# 2                Benzin       Automatik  170 kW (231 PS)  2.997 cm³  08/2023
# 3                Benzin       Automatik  170 kW (231 PS)  2.997 cm³  08/2023
# 4                Diesel       Automatik  125 kW (170 PS)  2.143 cm³      Neu
#
#    ...  anzahlSitzplaetze anzahlderTueren  schadstoffklasse umweltplakette  \
# 0  ...                5.0             4/5             Euro5       4 (Grün)
# 1  ...                5.0             4/5             Euro6       4 (Grün)
# 2  ...                2.0             2/3             Euro5       4 (Grün)
# 3  ...                2.0             2/3             Euro5       4 (Grün)
# 4  ...                5.0             4/5             Euro6       4 (Grün)
#
#            klimatisierung                                   einparkhilfe  \
# 0          Klimaautomatik          Vorne, Hinten, Selbstlenkende Systeme
# 1  2-Zonen-Klimaautomatik                                         Hinten
# 2          Klimaautomatik                                  Vorne, Hinten
# 3          Klimaautomatik                                  Vorne, Hinten
# 4             Klimaanlage  Vorne, Hinten, Kamera, Selbstlenkende Systeme
#
#                                airbags    innenausstattung  \
# 0  Front-, Seiten- und weitere Airbags  Alcantara, Schwarz
# 1  Front-, Seiten- und weitere Airbags      Stoff, Schwarz
# 2            Front- und Seiten-Airbags  Vollleder, Schwarz
# 3            Front- und Seiten-Airbags  Vollleder, Schwarz
# 4  Front-, Seiten- und weitere Airbags      Stoff, Schwarz
#
#                                          ausstattung Unnamed: 23
# 0  ABS,Alarmanlage,Armlehne,Bordcomputer,CD-Spiel...         NaN
# 1  ABS,Ambiente-Beleuchtung,Armlehne,Berganfahras...         NaN
# 2  ABS,Armlehne,Berganfahrassistent,Bi-Xenon Sche...         NaN
# 3  ABS,Armlehne,Berganfahrassistent,Bi-Xenon Sche...         NaN
# 4  ABS,Abstandswarner,Armlehne,Berganfahrassisten...         NaN
#
# [5 rows x 24 columns]

# %% [markdown]
# ---

# %%
df['preis']
# Out:
# 0        9.797 €
# 1       13.890 €
# 2       19.990 €
# 3       19.990 €
# 4       17.450 €
#           ...
# 9995    14.900 €
# 9996    17.990 €
# 9997    16.490 €
# 9998    14.749 €
# 9999    12.950 €
# Name: preis, Length: 10000, dtype: object

# %%
type(df.loc[0, 'preis'])
# Out:
# str

# %%
df["preis"] = df["preis"].str.replace('.', '')
# Out:
# /Applications/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
#   """Entry point for launching an IPython kernel.

# %%
df.head()
# Out:
#            marke   modell    preis   kilometer erstzulassung  \
# 0     Volkswagen     Golf   9797 €   79.449 km       04/2011
# 1     Volkswagen     Golf  13890 €   76.486 km       01/2015
# 2  Mercedes-Benz  SLK 300  19990 €   84.000 km       07/2009
# 3  Mercedes-Benz  SLK 350  19990 €   84.000 km       07/2009
# 4  Mercedes-Benz    A 220  17450 €  109.252 km       12/2012
#
#           kraftstoffart        getriebe         leistung    hubraum       hu  \
# 0                Benzin  Schaltgetriebe    63 kW (86 PS)  1.197 cm³      Neu
# 1  Benzin, E10-geeignet  Schaltgetriebe   92 kW (125 PS)  1.395 cm³      Neu
# 2                Benzin       Automatik  170 kW (231 PS)  2.997 cm³  08/2023
# 3                Benzin       Automatik  170 kW (231 PS)  2.997 cm³  08/2023
# 4                Diesel       Automatik  125 kW (170 PS)  2.143 cm³      Neu
#
#    ...  anzahlSitzplaetze anzahlderTueren  schadstoffklasse umweltplakette  \
# 0  ...                5.0             4/5             Euro5       4 (Grün)
# 1  ...                5.0             4/5             Euro6       4 (Grün)
# 2  ...                2.0             2/3             Euro5       4 (Grün)
# 3  ...                2.0             2/3             Euro5       4 (Grün)
# 4  ...                5.0             4/5             Euro6       4 (Grün)
#
#            klimatisierung                                   einparkhilfe  \
# 0          Klimaautomatik          Vorne, Hinten, Selbstlenkende Systeme
# 1  2-Zonen-Klimaautomatik                                         Hinten
# 2          Klimaautomatik                                  Vorne, Hinten
# 3          Klimaautomatik                                  Vorne, Hinten
# 4             Klimaanlage  Vorne, Hinten, Kamera, Selbstlenkende Systeme
#
#                                airbags    innenausstattung  \
# 0  Front-, Seiten- und weitere Airbags  Alcantara, Schwarz
# 1  Front-, Seiten- und weitere Airbags      Stoff, Schwarz
# 2            Front- und Seiten-Airbags  Vollleder, Schwarz
# 3            Front- und Seiten-Airbags  Vollleder, Schwarz
# 4  Front-, Seiten- und weitere Airbags      Stoff, Schwarz
#
#                                          ausstattung Unnamed: 23
# 0  ABS,Alarmanlage,Armlehne,Bordcomputer,CD-Spiel...         NaN
# 1  ABS,Ambiente-Beleuchtung,Armlehne,Berganfahras...         NaN
# 2  ABS,Armlehne,Berganfahrassistent,Bi-Xenon Sche...         NaN
# 3  ABS,Armlehne,Berganfahrassistent,Bi-Xenon Sche...         NaN
# 4  ABS,Abstandswarner,Armlehne,Berganfahrassisten...         NaN
#
# [5 rows x 24 columns]

# %%
df.shape
# Out:
# (10000, 24)

# %%
df.count(0)
# Out:
# marke                      9541
# modell                     9541
# preis                      9523
# kilometer                  9501
# erstzulassung              9466
# kraftstoffart              9523
# getriebe                   9522
# leistung                   9523
# hubraum                    9494
# hu                         8530
# plz                        9541
# farbe                      9517
# anzahlderFahrzeughalter    7927
# kategorie                  9523
# anzahlSitzplaetze          9508
# anzahlderTueren            9520
# schadstoffklasse           8589
# umweltplakette             9014
# klimatisierung             9087
# einparkhilfe               9444
# airbags                    9500
# innenausstattung           9521
# ausstattung                9522
# Unnamed: 23                   0
# dtype: int64

# %%
type(df.preis[0])
# Out:
# str

# %%
df.loc[0, 'preis']
# Out:
# '9797 €'

# %%
df.loc[0, 'preis'].split(' ')
# Out:
# ['9797', '€']

# %%
df.loc[0, 'preis'].split(' ')[0]
# Out:
# '9797'

# %%
type(df.loc[0, 'preis'].split(' ')[0])
# Out:
# str

# %%
int(df.loc[0, 'preis'].split(' ')[0])
# Out:
# 9797

# %%
for i in trange(len(df)):
    try:
        df.loc[i, 'preis'] = int(df.loc[i, 'preis'].split(' ')[0])
    except:
        df.loc[i, 'preis'] = 'Nan'
# Out:
#   0%|          | 0/10000 [00:00<?, ?it/s]

# %%
df.preis.head()
# Out:
# 0     9797
# 1    13890
# 2    19990
# 3    19990
# 4    17450
# Name: preis, dtype: object

# %%
type(df.preis[0])
# Out:
# int

# %% [markdown]
# ---

# %% [markdown]
# ## `for-loop` vermeiden

# %%
df = pd.read_csv('./csv/replace_split/cars.csv', index_col=0)

# %%
df["preis"] = df["preis"].str.replace('.', '')
# Out:
# /Applications/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
#   """Entry point for launching an IPython kernel.

# %%
df.head(3)
# Out:
#            marke   modell    preis  kilometer erstzulassung  \
# 0     Volkswagen     Golf   9797 €  79.449 km       04/2011
# 1     Volkswagen     Golf  13890 €  76.486 km       01/2015
# 2  Mercedes-Benz  SLK 300  19990 €  84.000 km       07/2009
#
#           kraftstoffart        getriebe         leistung    hubraum       hu  \
# 0                Benzin  Schaltgetriebe    63 kW (86 PS)  1.197 cm³      Neu
# 1  Benzin, E10-geeignet  Schaltgetriebe   92 kW (125 PS)  1.395 cm³      Neu
# 2                Benzin       Automatik  170 kW (231 PS)  2.997 cm³  08/2023
#
#    ...  anzahlSitzplaetze anzahlderTueren  schadstoffklasse umweltplakette  \
# 0  ...                5.0             4/5             Euro5       4 (Grün)
# 1  ...                5.0             4/5             Euro6       4 (Grün)
# 2  ...                2.0             2/3             Euro5       4 (Grün)
#
#            klimatisierung                           einparkhilfe  \
# 0          Klimaautomatik  Vorne, Hinten, Selbstlenkende Systeme
# 1  2-Zonen-Klimaautomatik                                 Hinten
# 2          Klimaautomatik                          Vorne, Hinten
#
#                                airbags    innenausstattung  \
# 0  Front-, Seiten- und weitere Airbags  Alcantara, Schwarz
# 1  Front-, Seiten- und weitere Airbags      Stoff, Schwarz
# 2            Front- und Seiten-Airbags  Vollleder, Schwarz
#
#                                          ausstattung Unnamed: 23
# 0  ABS,Alarmanlage,Armlehne,Bordcomputer,CD-Spiel...         NaN
# 1  ABS,Ambiente-Beleuchtung,Armlehne,Berganfahras...         NaN
# 2  ABS,Armlehne,Berganfahrassistent,Bi-Xenon Sche...         NaN
#
# [3 rows x 24 columns]

# %%
df_preis_null = df[df['preis'].isna()]
df_preis_null
# Out:
#               marke modell preis kilometer erstzulassung kraftstoffart  \
# 10              NaN    NaN   NaN       NaN           NaN           NaN
# 75    Mercedes-Benz  A 180   NaN       NaN           NaN           NaN
# 87              NaN    NaN   NaN       NaN           NaN           NaN
# 90              NaN    NaN   NaN       NaN           NaN           NaN
# 117             NaN    NaN   NaN       NaN           NaN           NaN
# ...             ...    ...   ...       ...           ...           ...
# 9902            NaN    NaN   NaN       NaN           NaN           NaN
# 9923            NaN    NaN   NaN       NaN           NaN           NaN
# 9944            NaN    NaN   NaN       NaN           NaN           NaN
# 9965            NaN    NaN   NaN       NaN           NaN           NaN
# 9986            NaN    NaN   NaN       NaN           NaN           NaN
#
#      getriebe leistung hubraum   hu  ...  anzahlSitzplaetze anzahlderTueren  \
# 10        NaN      NaN     NaN  NaN  ...                NaN             NaN
# 75        NaN      NaN     NaN  NaN  ...                NaN             NaN
# 87        NaN      NaN     NaN  NaN  ...                NaN             NaN
# 90        NaN      NaN     NaN  NaN  ...                NaN             NaN
# 117       NaN      NaN     NaN  NaN  ...                NaN             NaN
# ...       ...      ...     ...  ...  ...                ...             ...
# 9902      NaN      NaN     NaN  NaN  ...                NaN             NaN
# 9923      NaN      NaN     NaN  NaN  ...                NaN             NaN
# 9944      NaN      NaN     NaN  NaN  ...                NaN             NaN
# 9965      NaN      NaN     NaN  NaN  ...                NaN             NaN
# 9986      NaN      NaN     NaN  NaN  ...                NaN             NaN
#
#       schadstoffklasse umweltplakette  klimatisierung einparkhilfe airbags  \
# 10                 NaN            NaN             NaN          NaN     NaN
# 75                 NaN            NaN             NaN          NaN     NaN
# 87                 NaN            NaN             NaN          NaN     NaN
# 90                 NaN            NaN             NaN          NaN     NaN
# 117                NaN            NaN             NaN          NaN     NaN
# ...                ...            ...             ...          ...     ...
# 9902               NaN            NaN             NaN          NaN     NaN
# 9923               NaN            NaN             NaN          NaN     NaN
# 9944               NaN            NaN             NaN          NaN     NaN
# 9965               NaN            NaN             NaN          NaN     NaN
# 9986               NaN            NaN             NaN          NaN     NaN
#
#      innenausstattung ausstattung Unnamed: 23
# 10                NaN         NaN         NaN
# 75                NaN         NaN         NaN
# 87                NaN         NaN         NaN
# 90                NaN         NaN         NaN
# 117               NaN         NaN         NaN
# ...               ...         ...         ...
# 9902              NaN         NaN         NaN
# 9923              NaN         NaN         NaN
# 9944              NaN         NaN         NaN
# 9965              NaN         NaN         NaN
# 9986              NaN         NaN         NaN
#
# [477 rows x 24 columns]

# %%
df = df.dropna(subset=['preis'])
df.shape
# Out:
# (9523, 24)

# %%
df["preis"] = df.preis.str.split(" ", expand=True)[0].astype(int)

# %%
df.head()
# Out:
#            marke   modell  preis   kilometer erstzulassung  \
# 0     Volkswagen     Golf   9797   79.449 km       04/2011
# 1     Volkswagen     Golf  13890   76.486 km       01/2015
# 2  Mercedes-Benz  SLK 300  19990   84.000 km       07/2009
# 3  Mercedes-Benz  SLK 350  19990   84.000 km       07/2009
# 4  Mercedes-Benz    A 220  17450  109.252 km       12/2012
#
#           kraftstoffart        getriebe         leistung    hubraum       hu  \
# 0                Benzin  Schaltgetriebe    63 kW (86 PS)  1.197 cm³      Neu
# 1  Benzin, E10-geeignet  Schaltgetriebe   92 kW (125 PS)  1.395 cm³      Neu
# 2                Benzin       Automatik  170 kW (231 PS)  2.997 cm³  08/2023
# 3                Benzin       Automatik  170 kW (231 PS)  2.997 cm³  08/2023
# 4                Diesel       Automatik  125 kW (170 PS)  2.143 cm³      Neu
#
#    ...  anzahlSitzplaetze anzahlderTueren  schadstoffklasse umweltplakette  \
# 0  ...                5.0             4/5             Euro5       4 (Grün)
# 1  ...                5.0             4/5             Euro6       4 (Grün)
# 2  ...                2.0             2/3             Euro5       4 (Grün)
# 3  ...                2.0             2/3             Euro5       4 (Grün)
# 4  ...                5.0             4/5             Euro6       4 (Grün)
#
#            klimatisierung                                   einparkhilfe  \
# 0          Klimaautomatik          Vorne, Hinten, Selbstlenkende Systeme
# 1  2-Zonen-Klimaautomatik                                         Hinten
# 2          Klimaautomatik                                  Vorne, Hinten
# 3          Klimaautomatik                                  Vorne, Hinten
# 4             Klimaanlage  Vorne, Hinten, Kamera, Selbstlenkende Systeme
#
#                                airbags    innenausstattung  \
# 0  Front-, Seiten- und weitere Airbags  Alcantara, Schwarz
# 1  Front-, Seiten- und weitere Airbags      Stoff, Schwarz
# 2            Front- und Seiten-Airbags  Vollleder, Schwarz
# 3            Front- und Seiten-Airbags  Vollleder, Schwarz
# 4  Front-, Seiten- und weitere Airbags      Stoff, Schwarz
#
#                                          ausstattung Unnamed: 23
# 0  ABS,Alarmanlage,Armlehne,Bordcomputer,CD-Spiel...         NaN
# 1  ABS,Ambiente-Beleuchtung,Armlehne,Berganfahras...         NaN
# 2  ABS,Armlehne,Berganfahrassistent,Bi-Xenon Sche...         NaN
# 3  ABS,Armlehne,Berganfahrassistent,Bi-Xenon Sche...         NaN
# 4  ABS,Abstandswarner,Armlehne,Berganfahrassisten...         NaN
#
# [5 rows x 24 columns]

# %%
df_final = pd.concat([df, df_preis_null])

# %%
df_final
# Out:
#               marke   modell  preis   kilometer erstzulassung  \
# 0        Volkswagen     Golf   9797   79.449 km       04/2011
# 1        Volkswagen     Golf  13890   76.486 km       01/2015
# 2     Mercedes-Benz  SLK 300  19990   84.000 km       07/2009
# 3     Mercedes-Benz  SLK 350  19990   84.000 km       07/2009
# 4     Mercedes-Benz    A 220  17450  109.252 km       12/2012
# ...             ...      ...    ...         ...           ...
# 9902            NaN      NaN    NaN         NaN           NaN
# 9923            NaN      NaN    NaN         NaN           NaN
# 9944            NaN      NaN    NaN         NaN           NaN
# 9965            NaN      NaN    NaN         NaN           NaN
# 9986            NaN      NaN    NaN         NaN           NaN
#
#              kraftstoffart        getriebe         leistung    hubraum  \
# 0                   Benzin  Schaltgetriebe    63 kW (86 PS)  1.197 cm³
# 1     Benzin, E10-geeignet  Schaltgetriebe   92 kW (125 PS)  1.395 cm³
# 2                   Benzin       Automatik  170 kW (231 PS)  2.997 cm³
# 3                   Benzin       Automatik  170 kW (231 PS)  2.997 cm³
# 4                   Diesel       Automatik  125 kW (170 PS)  2.143 cm³
# ...                    ...             ...              ...        ...
# 9902                   NaN             NaN              NaN        NaN
# 9923                   NaN             NaN              NaN        NaN
# 9944                   NaN             NaN              NaN        NaN
# 9965                   NaN             NaN              NaN        NaN
# 9986                   NaN             NaN              NaN        NaN
#
#            hu  ...  anzahlSitzplaetze anzahlderTueren  schadstoffklasse  \
# 0         Neu  ...                5.0             4/5             Euro5
# 1         Neu  ...                5.0             4/5             Euro6
# 2     08/2023  ...                2.0             2/3             Euro5
# 3     08/2023  ...                2.0             2/3             Euro5
# 4         Neu  ...                5.0             4/5             Euro6
# ...       ...  ...                ...             ...               ...
# 9902      NaN  ...                NaN             NaN               NaN
# 9923      NaN  ...                NaN             NaN               NaN
# 9944      NaN  ...                NaN             NaN               NaN
# 9965      NaN  ...                NaN             NaN               NaN
# 9986      NaN  ...                NaN             NaN               NaN
#
#      umweltplakette          klimatisierung  \
# 0          4 (Grün)          Klimaautomatik
# 1          4 (Grün)  2-Zonen-Klimaautomatik
# 2          4 (Grün)          Klimaautomatik
# 3          4 (Grün)          Klimaautomatik
# 4          4 (Grün)             Klimaanlage
# ...             ...                     ...
# 9902            NaN                     NaN
# 9923            NaN                     NaN
# 9944            NaN                     NaN
# 9965            NaN                     NaN
# 9986            NaN                     NaN
#
#                                        einparkhilfe  \
# 0             Vorne, Hinten, Selbstlenkende Systeme
# 1                                            Hinten
# 2                                     Vorne, Hinten
# 3                                     Vorne, Hinten
# 4     Vorne, Hinten, Kamera, Selbstlenkende Systeme
# ...                                             ...
# 9902                                            NaN
# 9923                                            NaN
# 9944                                            NaN
# 9965                                            NaN
# 9986                                            NaN
#
#                                   airbags    innenausstattung  \
# 0     Front-, Seiten- und weitere Airbags  Alcantara, Schwarz
# 1     Front-, Seiten- und weitere Airbags      Stoff, Schwarz
# 2               Front- und Seiten-Airbags  Vollleder, Schwarz
# 3               Front- und Seiten-Airbags  Vollleder, Schwarz
# 4     Front-, Seiten- und weitere Airbags      Stoff, Schwarz
# ...                                   ...                 ...
# 9902                                  NaN                 NaN
# 9923                                  NaN                 NaN
# 9944                                  NaN                 NaN
# 9965                                  NaN                 NaN
# 9986                                  NaN                 NaN
#
#                                             ausstattung Unnamed: 23
# 0     ABS,Alarmanlage,Armlehne,Bordcomputer,CD-Spiel...         NaN
# 1     ABS,Ambiente-Beleuchtung,Armlehne,Berganfahras...         NaN
# 2     ABS,Armlehne,Berganfahrassistent,Bi-Xenon Sche...         NaN
# 3     ABS,Armlehne,Berganfahrassistent,Bi-Xenon Sche...         NaN
# 4     ABS,Abstandswarner,Armlehne,Berganfahrassisten...         NaN
# ...                                                 ...         ...
# 9902                                                NaN         NaN
# 9923                                                NaN         NaN
# 9944                                                NaN         NaN
# 9965                                                NaN         NaN
# 9986                                                NaN         NaN
#
# [10000 rows x 24 columns]

# %%
df_final.sort_index()
# Out:
#               marke   modell  preis   kilometer erstzulassung  \
# 0        Volkswagen     Golf   9797   79.449 km       04/2011
# 1        Volkswagen     Golf  13890   76.486 km       01/2015
# 2     Mercedes-Benz  SLK 300  19990   84.000 km       07/2009
# 3     Mercedes-Benz  SLK 350  19990   84.000 km       07/2009
# 4     Mercedes-Benz    A 220  17450  109.252 km       12/2012
# ...             ...      ...    ...         ...           ...
# 9995     Volkswagen     Golf  14900   93.500 km       09/2013
# 9996           Audi       A4  17990   96.500 km       07/2013
# 9997     Volkswagen     Golf  16490  103.000 km       02/2014
# 9998            BMW      320  14749   94.505 km       11/2011
# 9999     Volkswagen     Golf  12950   84.500 km       11/2014
#
#              kraftstoffart        getriebe         leistung    hubraum  \
# 0                   Benzin  Schaltgetriebe    63 kW (86 PS)  1.197 cm³
# 1     Benzin, E10-geeignet  Schaltgetriebe   92 kW (125 PS)  1.395 cm³
# 2                   Benzin       Automatik  170 kW (231 PS)  2.997 cm³
# 3                   Benzin       Automatik  170 kW (231 PS)  2.997 cm³
# 4                   Diesel       Automatik  125 kW (170 PS)  2.143 cm³
# ...                    ...             ...              ...        ...
# 9995                Benzin       Automatik   90 kW (122 PS)  1.395 cm³
# 9996                Benzin       Automatik  165 kW (224 PS)  1.984 cm³
# 9997                Benzin  Schaltgetriebe  162 kW (220 PS)  1.984 cm³
# 9998                Diesel       Automatik  135 kW (184 PS)  1.995 cm³
# 9999                Benzin  Schaltgetriebe  110 kW (150 PS)  1.395 cm³
#
#            hu  ...  anzahlSitzplaetze anzahlderTueren  schadstoffklasse  \
# 0         Neu  ...                5.0             4/5             Euro5
# 1         Neu  ...                5.0             4/5             Euro6
# 2     08/2023  ...                2.0             2/3             Euro5
# 3     08/2023  ...                2.0             2/3             Euro5
# 4         Neu  ...                5.0             4/5             Euro6
# ...       ...  ...                ...             ...               ...
# 9995      Neu  ...                5.0             4/5             Euro5
# 9996      Neu  ...                5.0             4/5             Euro6
# 9997  06/2023  ...                5.0             2/3             Euro6
# 9998  01/2024  ...                5.0             4/5             Euro5
# 9999      Neu  ...                5.0             4/5               NaN
#
#      umweltplakette          klimatisierung  \
# 0          4 (Grün)          Klimaautomatik
# 1          4 (Grün)  2-Zonen-Klimaautomatik
# 2          4 (Grün)          Klimaautomatik
# 3          4 (Grün)          Klimaautomatik
# 4          4 (Grün)             Klimaanlage
# ...             ...                     ...
# 9995       4 (Grün)  2-Zonen-Klimaautomatik
# 9996       4 (Grün)  3-Zonen-Klimaautomatik
# 9997       4 (Grün)          Klimaautomatik
# 9998       4 (Grün)  2-Zonen-Klimaautomatik
# 9999            NaN  2-Zonen-Klimaautomatik
#
#                                        einparkhilfe  \
# 0             Vorne, Hinten, Selbstlenkende Systeme
# 1                                            Hinten
# 2                                     Vorne, Hinten
# 3                                     Vorne, Hinten
# 4     Vorne, Hinten, Kamera, Selbstlenkende Systeme
# ...                                             ...
# 9995  Vorne, Hinten, Kamera, Selbstlenkende Systeme
# 9996                                  Vorne, Hinten
# 9997                                  Vorne, Hinten
# 9998                                         Hinten
# 9999          Vorne, Hinten, Selbstlenkende Systeme
#
#                                   airbags    innenausstattung  \
# 0     Front-, Seiten- und weitere Airbags  Alcantara, Schwarz
# 1     Front-, Seiten- und weitere Airbags      Stoff, Schwarz
# 2               Front- und Seiten-Airbags  Vollleder, Schwarz
# 3               Front- und Seiten-Airbags  Vollleder, Schwarz
# 4     Front-, Seiten- und weitere Airbags      Stoff, Schwarz
# ...                                   ...                 ...
# 9995  Front-, Seiten- und weitere Airbags  Teilleder, Schwarz
# 9996  Front-, Seiten- und weitere Airbags      Stoff, Schwarz
# 9997  Front-, Seiten- und weitere Airbags      Stoff, Schwarz
# 9998  Front-, Seiten- und weitere Airbags  Vollleder, Schwarz
# 9999  Front-, Seiten- und weitere Airbags               Stoff
#
#                                             ausstattung Unnamed: 23
# 0     ABS,Alarmanlage,Armlehne,Bordcomputer,CD-Spiel...         NaN
# 1     ABS,Ambiente-Beleuchtung,Armlehne,Berganfahras...         NaN
# 2     ABS,Armlehne,Berganfahrassistent,Bi-Xenon Sche...         NaN
# 3     ABS,Armlehne,Berganfahrassistent,Bi-Xenon Sche...         NaN
# 4     ABS,Abstandswarner,Armlehne,Berganfahrassisten...         NaN
# ...                                                 ...         ...
# 9995  Abstandstempomat,Alarmanlage,Ambiente-Beleucht...         NaN
# 9996  ABS,Armlehne,Bi-Xenon Scheinwerfer,Bluetooth,B...         NaN
# 9997  ABS,Alarmanlage,Ambiente-Beleuchtung,Armlehne,...         NaN
# 9998  ABS,Adaptives Kurvenlicht,Armlehne,Bluetooth,B...         NaN
# 9999  ABS,Adaptives Kurvenlicht,Armlehne,Berganfahra...         NaN
#
# [10000 rows x 24 columns]

# %% [markdown]
# ---

# %% [markdown]
# ## Übung: Cars Datensatz Feature `Kilometer` Preprocessing

# %%
df = df_final.copy()

# %% [markdown]
# ### 1) Values checken

# %%
df.count(0)
# Out:
# marke                      9541
# modell                     9541
# preis                      9523
# kilometer                  9501
# erstzulassung              9466
# kraftstoffart              9523
# getriebe                   9522
# leistung                   9523
# hubraum                    9494
# hu                         8530
# plz                        9541
# farbe                      9517
# anzahlderFahrzeughalter    7927
# kategorie                  9523
# anzahlSitzplaetze          9508
# anzahlderTueren            9520
# schadstoffklasse           8589
# umweltplakette             9014
# klimatisierung             9087
# einparkhilfe               9444
# airbags                    9500
# innenausstattung           9521
# ausstattung                9522
# Unnamed: 23                   0
# dtype: int64

# %% [markdown]
# ### 2) `.replace()`

# %%
df["kilometer"] = df["kilometer"].str.replace('.', '')
# Out:
# /Applications/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
#   """Entry point for launching an IPython kernel.

# %%
df.head()
# Out:
#            marke   modell  preis  kilometer erstzulassung  \
# 0     Volkswagen     Golf   9797   79449 km       04/2011
# 1     Volkswagen     Golf  13890   76486 km       01/2015
# 2  Mercedes-Benz  SLK 300  19990   84000 km       07/2009
# 3  Mercedes-Benz  SLK 350  19990   84000 km       07/2009
# 4  Mercedes-Benz    A 220  17450  109252 km       12/2012
#
#           kraftstoffart        getriebe         leistung    hubraum       hu  \
# 0                Benzin  Schaltgetriebe    63 kW (86 PS)  1.197 cm³      Neu
# 1  Benzin, E10-geeignet  Schaltgetriebe   92 kW (125 PS)  1.395 cm³      Neu
# 2                Benzin       Automatik  170 kW (231 PS)  2.997 cm³  08/2023
# 3                Benzin       Automatik  170 kW (231 PS)  2.997 cm³  08/2023
# 4                Diesel       Automatik  125 kW (170 PS)  2.143 cm³      Neu
#
#    ...  anzahlSitzplaetze anzahlderTueren  schadstoffklasse umweltplakette  \
# 0  ...                5.0             4/5             Euro5       4 (Grün)
# 1  ...                5.0             4/5             Euro6       4 (Grün)
# 2  ...                2.0             2/3             Euro5       4 (Grün)
# 3  ...                2.0             2/3             Euro5       4 (Grün)
# 4  ...                5.0             4/5             Euro6       4 (Grün)
#
#            klimatisierung                                   einparkhilfe  \
# 0          Klimaautomatik          Vorne, Hinten, Selbstlenkende Systeme
# 1  2-Zonen-Klimaautomatik                                         Hinten
# 2          Klimaautomatik                                  Vorne, Hinten
# 3          Klimaautomatik                                  Vorne, Hinten
# 4             Klimaanlage  Vorne, Hinten, Kamera, Selbstlenkende Systeme
#
#                                airbags    innenausstattung  \
# 0  Front-, Seiten- und weitere Airbags  Alcantara, Schwarz
# 1  Front-, Seiten- und weitere Airbags      Stoff, Schwarz
# 2            Front- und Seiten-Airbags  Vollleder, Schwarz
# 3            Front- und Seiten-Airbags  Vollleder, Schwarz
# 4  Front-, Seiten- und weitere Airbags      Stoff, Schwarz
#
#                                          ausstattung Unnamed: 23
# 0  ABS,Alarmanlage,Armlehne,Bordcomputer,CD-Spiel...         NaN
# 1  ABS,Ambiente-Beleuchtung,Armlehne,Berganfahras...         NaN
# 2  ABS,Armlehne,Berganfahrassistent,Bi-Xenon Sche...         NaN
# 3  ABS,Armlehne,Berganfahrassistent,Bi-Xenon Sche...         NaN
# 4  ABS,Abstandswarner,Armlehne,Berganfahrassisten...         NaN
#
# [5 rows x 24 columns]

# %% [markdown]
# ### 3) `.split()`

# %%
df_km_nan = df[df['kilometer'].isnull()]
# df_km_nan

# %%
df = df.dropna(subset=['kilometer'])
df.shape
# Out:
# (9501, 24)

# %%
df.loc[0, 'kilometer']
# Out:
# '79449\xa0km'

# %%
df.loc[0, 'kilometer'].split("\xa0")
# Out:
# ['79449', 'km']

# %%
df.loc[0, 'kilometer'].split("\xa0")[0]
# Out:
# '79449'

# %%
df["kilometer"] = df.kilometer.str.split("\xa0", expand=True)[0].astype(int)

# %%
df
# Out:
#               marke   modell  preis  kilometer erstzulassung  \
# 0        Volkswagen     Golf   9797      79449       04/2011
# 1        Volkswagen     Golf  13890      76486       01/2015
# 2     Mercedes-Benz  SLK 300  19990      84000       07/2009
# 3     Mercedes-Benz  SLK 350  19990      84000       07/2009
# 4     Mercedes-Benz    A 220  17450     109252       12/2012
# ...             ...      ...    ...        ...           ...
# 9995     Volkswagen     Golf  14900      93500       09/2013
# 9996           Audi       A4  17990      96500       07/2013
# 9997     Volkswagen     Golf  16490     103000       02/2014
# 9998            BMW      320  14749      94505       11/2011
# 9999     Volkswagen     Golf  12950      84500       11/2014
#
#              kraftstoffart        getriebe         leistung    hubraum  \
# 0                   Benzin  Schaltgetriebe    63 kW (86 PS)  1.197 cm³
# 1     Benzin, E10-geeignet  Schaltgetriebe   92 kW (125 PS)  1.395 cm³
# 2                   Benzin       Automatik  170 kW (231 PS)  2.997 cm³
# 3                   Benzin       Automatik  170 kW (231 PS)  2.997 cm³
# 4                   Diesel       Automatik  125 kW (170 PS)  2.143 cm³
# ...                    ...             ...              ...        ...
# 9995                Benzin       Automatik   90 kW (122 PS)  1.395 cm³
# 9996                Benzin       Automatik  165 kW (224 PS)  1.984 cm³
# 9997                Benzin  Schaltgetriebe  162 kW (220 PS)  1.984 cm³
# 9998                Diesel       Automatik  135 kW (184 PS)  1.995 cm³
# 9999                Benzin  Schaltgetriebe  110 kW (150 PS)  1.395 cm³
#
#            hu  ...  anzahlSitzplaetze anzahlderTueren  schadstoffklasse  \
# 0         Neu  ...                5.0             4/5             Euro5
# 1         Neu  ...                5.0             4/5             Euro6
# 2     08/2023  ...                2.0             2/3             Euro5
# 3     08/2023  ...                2.0             2/3             Euro5
# 4         Neu  ...                5.0             4/5             Euro6
# ...       ...  ...                ...             ...               ...
# 9995      Neu  ...                5.0             4/5             Euro5
# 9996      Neu  ...                5.0             4/5             Euro6
# 9997  06/2023  ...                5.0             2/3             Euro6
# 9998  01/2024  ...                5.0             4/5             Euro5
# 9999      Neu  ...                5.0             4/5               NaN
#
#      umweltplakette          klimatisierung  \
# 0          4 (Grün)          Klimaautomatik
# 1          4 (Grün)  2-Zonen-Klimaautomatik
# 2          4 (Grün)          Klimaautomatik
# 3          4 (Grün)          Klimaautomatik
# 4          4 (Grün)             Klimaanlage
# ...             ...                     ...
# 9995       4 (Grün)  2-Zonen-Klimaautomatik
# 9996       4 (Grün)  3-Zonen-Klimaautomatik
# 9997       4 (Grün)          Klimaautomatik
# 9998       4 (Grün)  2-Zonen-Klimaautomatik
# 9999            NaN  2-Zonen-Klimaautomatik
#
#                                        einparkhilfe  \
# 0             Vorne, Hinten, Selbstlenkende Systeme
# 1                                            Hinten
# 2                                     Vorne, Hinten
# 3                                     Vorne, Hinten
# 4     Vorne, Hinten, Kamera, Selbstlenkende Systeme
# ...                                             ...
# 9995  Vorne, Hinten, Kamera, Selbstlenkende Systeme
# 9996                                  Vorne, Hinten
# 9997                                  Vorne, Hinten
# 9998                                         Hinten
# 9999          Vorne, Hinten, Selbstlenkende Systeme
#
#                                   airbags    innenausstattung  \
# 0     Front-, Seiten- und weitere Airbags  Alcantara, Schwarz
# 1     Front-, Seiten- und weitere Airbags      Stoff, Schwarz
# 2               Front- und Seiten-Airbags  Vollleder, Schwarz
# 3               Front- und Seiten-Airbags  Vollleder, Schwarz
# 4     Front-, Seiten- und weitere Airbags      Stoff, Schwarz
# ...                                   ...                 ...
# 9995  Front-, Seiten- und weitere Airbags  Teilleder, Schwarz
# 9996  Front-, Seiten- und weitere Airbags      Stoff, Schwarz
# 9997  Front-, Seiten- und weitere Airbags      Stoff, Schwarz
# 9998  Front-, Seiten- und weitere Airbags  Vollleder, Schwarz
# 9999  Front-, Seiten- und weitere Airbags               Stoff
#
#                                             ausstattung Unnamed: 23
# 0     ABS,Alarmanlage,Armlehne,Bordcomputer,CD-Spiel...         NaN
# 1     ABS,Ambiente-Beleuchtung,Armlehne,Berganfahras...         NaN
# 2     ABS,Armlehne,Berganfahrassistent,Bi-Xenon Sche...         NaN
# 3     ABS,Armlehne,Berganfahrassistent,Bi-Xenon Sche...         NaN
# 4     ABS,Abstandswarner,Armlehne,Berganfahrassisten...         NaN
# ...                                                 ...         ...
# 9995  Abstandstempomat,Alarmanlage,Ambiente-Beleucht...         NaN
# 9996  ABS,Armlehne,Bi-Xenon Scheinwerfer,Bluetooth,B...         NaN
# 9997  ABS,Alarmanlage,Ambiente-Beleuchtung,Armlehne,...         NaN
# 9998  ABS,Adaptives Kurvenlicht,Armlehne,Bluetooth,B...         NaN
# 9999  ABS,Adaptives Kurvenlicht,Armlehne,Berganfahra...         NaN
#
# [9501 rows x 24 columns]

# %%
df_final = pd.concat([df, df_km_nan])
df_final
# Out:
#               marke   modell  preis kilometer erstzulassung  \
# 0        Volkswagen     Golf   9797     79449       04/2011
# 1        Volkswagen     Golf  13890     76486       01/2015
# 2     Mercedes-Benz  SLK 300  19990     84000       07/2009
# 3     Mercedes-Benz  SLK 350  19990     84000       07/2009
# 4     Mercedes-Benz    A 220  17450    109252       12/2012
# ...             ...      ...    ...       ...           ...
# 9902            NaN      NaN    NaN       NaN           NaN
# 9923            NaN      NaN    NaN       NaN           NaN
# 9944            NaN      NaN    NaN       NaN           NaN
# 9965            NaN      NaN    NaN       NaN           NaN
# 9986            NaN      NaN    NaN       NaN           NaN
#
#              kraftstoffart        getriebe         leistung    hubraum  \
# 0                   Benzin  Schaltgetriebe    63 kW (86 PS)  1.197 cm³
# 1     Benzin, E10-geeignet  Schaltgetriebe   92 kW (125 PS)  1.395 cm³
# 2                   Benzin       Automatik  170 kW (231 PS)  2.997 cm³
# 3                   Benzin       Automatik  170 kW (231 PS)  2.997 cm³
# 4                   Diesel       Automatik  125 kW (170 PS)  2.143 cm³
# ...                    ...             ...              ...        ...
# 9902                   NaN             NaN              NaN        NaN
# 9923                   NaN             NaN              NaN        NaN
# 9944                   NaN             NaN              NaN        NaN
# 9965                   NaN             NaN              NaN        NaN
# 9986                   NaN             NaN              NaN        NaN
#
#            hu  ...  anzahlSitzplaetze anzahlderTueren  schadstoffklasse  \
# 0         Neu  ...                5.0             4/5             Euro5
# 1         Neu  ...                5.0             4/5             Euro6
# 2     08/2023  ...                2.0             2/3             Euro5
# 3     08/2023  ...                2.0             2/3             Euro5
# 4         Neu  ...                5.0             4/5             Euro6
# ...       ...  ...                ...             ...               ...
# 9902      NaN  ...                NaN             NaN               NaN
# 9923      NaN  ...                NaN             NaN               NaN
# 9944      NaN  ...                NaN             NaN               NaN
# 9965      NaN  ...                NaN             NaN               NaN
# 9986      NaN  ...                NaN             NaN               NaN
#
#      umweltplakette          klimatisierung  \
# 0          4 (Grün)          Klimaautomatik
# 1          4 (Grün)  2-Zonen-Klimaautomatik
# 2          4 (Grün)          Klimaautomatik
# 3          4 (Grün)          Klimaautomatik
# 4          4 (Grün)             Klimaanlage
# ...             ...                     ...
# 9902            NaN                     NaN
# 9923            NaN                     NaN
# 9944            NaN                     NaN
# 9965            NaN                     NaN
# 9986            NaN                     NaN
#
#                                        einparkhilfe  \
# 0             Vorne, Hinten, Selbstlenkende Systeme
# 1                                            Hinten
# 2                                     Vorne, Hinten
# 3                                     Vorne, Hinten
# 4     Vorne, Hinten, Kamera, Selbstlenkende Systeme
# ...                                             ...
# 9902                                            NaN
# 9923                                            NaN
# 9944                                            NaN
# 9965                                            NaN
# 9986                                            NaN
#
#                                   airbags    innenausstattung  \
# 0     Front-, Seiten- und weitere Airbags  Alcantara, Schwarz
# 1     Front-, Seiten- und weitere Airbags      Stoff, Schwarz
# 2               Front- und Seiten-Airbags  Vollleder, Schwarz
# 3               Front- und Seiten-Airbags  Vollleder, Schwarz
# 4     Front-, Seiten- und weitere Airbags      Stoff, Schwarz
# ...                                   ...                 ...
# 9902                                  NaN                 NaN
# 9923                                  NaN                 NaN
# 9944                                  NaN                 NaN
# 9965                                  NaN                 NaN
# 9986                                  NaN                 NaN
#
#                                             ausstattung Unnamed: 23
# 0     ABS,Alarmanlage,Armlehne,Bordcomputer,CD-Spiel...         NaN
# 1     ABS,Ambiente-Beleuchtung,Armlehne,Berganfahras...         NaN
# 2     ABS,Armlehne,Berganfahrassistent,Bi-Xenon Sche...         NaN
# 3     ABS,Armlehne,Berganfahrassistent,Bi-Xenon Sche...         NaN
# 4     ABS,Abstandswarner,Armlehne,Berganfahrassisten...         NaN
# ...                                                 ...         ...
# 9902                                                NaN         NaN
# 9923                                                NaN         NaN
# 9944                                                NaN         NaN
# 9965                                                NaN         NaN
# 9986                                                NaN         NaN
#
# [10000 rows x 24 columns]

# %%
df_final.sort_index()
# Out:
#               marke   modell  preis kilometer erstzulassung  \
# 0        Volkswagen     Golf   9797     79449       04/2011
# 1        Volkswagen     Golf  13890     76486       01/2015
# 2     Mercedes-Benz  SLK 300  19990     84000       07/2009
# 3     Mercedes-Benz  SLK 350  19990     84000       07/2009
# 4     Mercedes-Benz    A 220  17450    109252       12/2012
# ...             ...      ...    ...       ...           ...
# 9995     Volkswagen     Golf  14900     93500       09/2013
# 9996           Audi       A4  17990     96500       07/2013
# 9997     Volkswagen     Golf  16490    103000       02/2014
# 9998            BMW      320  14749     94505       11/2011
# 9999     Volkswagen     Golf  12950     84500       11/2014
#
#              kraftstoffart        getriebe         leistung    hubraum  \
# 0                   Benzin  Schaltgetriebe    63 kW (86 PS)  1.197 cm³
# 1     Benzin, E10-geeignet  Schaltgetriebe   92 kW (125 PS)  1.395 cm³
# 2                   Benzin       Automatik  170 kW (231 PS)  2.997 cm³
# 3                   Benzin       Automatik  170 kW (231 PS)  2.997 cm³
# 4                   Diesel       Automatik  125 kW (170 PS)  2.143 cm³
# ...                    ...             ...              ...        ...
# 9995                Benzin       Automatik   90 kW (122 PS)  1.395 cm³
# 9996                Benzin       Automatik  165 kW (224 PS)  1.984 cm³
# 9997                Benzin  Schaltgetriebe  162 kW (220 PS)  1.984 cm³
# 9998                Diesel       Automatik  135 kW (184 PS)  1.995 cm³
# 9999                Benzin  Schaltgetriebe  110 kW (150 PS)  1.395 cm³
#
#            hu  ...  anzahlSitzplaetze anzahlderTueren  schadstoffklasse  \
# 0         Neu  ...                5.0             4/5             Euro5
# 1         Neu  ...                5.0             4/5             Euro6
# 2     08/2023  ...                2.0             2/3             Euro5
# 3     08/2023  ...                2.0             2/3             Euro5
# 4         Neu  ...                5.0             4/5             Euro6
# ...       ...  ...                ...             ...               ...
# 9995      Neu  ...                5.0             4/5             Euro5
# 9996      Neu  ...                5.0             4/5             Euro6
# 9997  06/2023  ...                5.0             2/3             Euro6
# 9998  01/2024  ...                5.0             4/5             Euro5
# 9999      Neu  ...                5.0             4/5               NaN
#
#      umweltplakette          klimatisierung  \
# 0          4 (Grün)          Klimaautomatik
# 1          4 (Grün)  2-Zonen-Klimaautomatik
# 2          4 (Grün)          Klimaautomatik
# 3          4 (Grün)          Klimaautomatik
# 4          4 (Grün)             Klimaanlage
# ...             ...                     ...
# 9995       4 (Grün)  2-Zonen-Klimaautomatik
# 9996       4 (Grün)  3-Zonen-Klimaautomatik
# 9997       4 (Grün)          Klimaautomatik
# 9998       4 (Grün)  2-Zonen-Klimaautomatik
# 9999            NaN  2-Zonen-Klimaautomatik
#
#                                        einparkhilfe  \
# 0             Vorne, Hinten, Selbstlenkende Systeme
# 1                                            Hinten
# 2                                     Vorne, Hinten
# 3                                     Vorne, Hinten
# 4     Vorne, Hinten, Kamera, Selbstlenkende Systeme
# ...                                             ...
# 9995  Vorne, Hinten, Kamera, Selbstlenkende Systeme
# 9996                                  Vorne, Hinten
# 9997                                  Vorne, Hinten
# 9998                                         Hinten
# 9999          Vorne, Hinten, Selbstlenkende Systeme
#
#                                   airbags    innenausstattung  \
# 0     Front-, Seiten- und weitere Airbags  Alcantara, Schwarz
# 1     Front-, Seiten- und weitere Airbags      Stoff, Schwarz
# 2               Front- und Seiten-Airbags  Vollleder, Schwarz
# 3               Front- und Seiten-Airbags  Vollleder, Schwarz
# 4     Front-, Seiten- und weitere Airbags      Stoff, Schwarz
# ...                                   ...                 ...
# 9995  Front-, Seiten- und weitere Airbags  Teilleder, Schwarz
# 9996  Front-, Seiten- und weitere Airbags      Stoff, Schwarz
# 9997  Front-, Seiten- und weitere Airbags      Stoff, Schwarz
# 9998  Front-, Seiten- und weitere Airbags  Vollleder, Schwarz
# 9999  Front-, Seiten- und weitere Airbags               Stoff
#
#                                             ausstattung Unnamed: 23
# 0     ABS,Alarmanlage,Armlehne,Bordcomputer,CD-Spiel...         NaN
# 1     ABS,Ambiente-Beleuchtung,Armlehne,Berganfahras...         NaN
# 2     ABS,Armlehne,Berganfahrassistent,Bi-Xenon Sche...         NaN
# 3     ABS,Armlehne,Berganfahrassistent,Bi-Xenon Sche...         NaN
# 4     ABS,Abstandswarner,Armlehne,Berganfahrassisten...         NaN
# ...                                                 ...         ...
# 9995  Abstandstempomat,Alarmanlage,Ambiente-Beleucht...         NaN
# 9996  ABS,Armlehne,Bi-Xenon Scheinwerfer,Bluetooth,B...         NaN
# 9997  ABS,Alarmanlage,Ambiente-Beleuchtung,Armlehne,...         NaN
# 9998  ABS,Adaptives Kurvenlicht,Armlehne,Bluetooth,B...         NaN
# 9999  ABS,Adaptives Kurvenlicht,Armlehne,Berganfahra...         NaN
#
# [10000 rows x 24 columns]

# %%
df.preis.mean()
# Out:
# 19071.815177349752

# %%
df.kilometer.mean()
# Out:
# 91602.25870960951
