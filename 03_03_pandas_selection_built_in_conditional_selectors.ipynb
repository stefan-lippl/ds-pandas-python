# %% [markdown]
# ![title](./pic/selecting/built_in/1_title.png)

# %%
import pandas as pd
import random

# %%
df = pd.read_csv('./csv/titanic.csv')
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Cabin Embarked
# 0   330911   7.8292   NaN        Q
# 1   363272   7.0000   NaN        S
# 2   240276   9.6875   NaN        Q
# 3   315154   8.6625   NaN        S
# 4  3101298  12.2875   NaN        S

# %% [markdown]
# <br>
#
# `Pandas` verfügt über einige **eingebaute bedingte Selektoren**, von denen ist die wichtigsten in diesem Notebook hervorhebe. Diese Art von Selektoren sollen dir dabei helfen, schnell einen Überblick über dein `DataFrame` zu erhalten und gewisse Einträge mit gewissen Werten zügig in Erfahrung zu bringen.

# %% [markdown]
# ---

# %% [markdown]
# ## `.copy()`

# %% [markdown]
# Die Methode Pandas `.copy()` wird verwendet, um eine **Kopie eines Pandas-Objekts** zu erstellen. Variablen werden auch verwendet, um eine Kopie eines Objekts zu erzeugen, aber Variablen sind nur Zeiger auf ein Objekt und jede Änderung der neuen Daten wird auch die vorherigen Daten ändern. Mit `.copy()` wird ein neues Objekt im Arbeitsspeicher erstellt.

# %% [markdown]
# ![title](./pic/aditional_functions/copy/2_copy.png)

# %% [markdown]
# ### Ohne `.copy()` sondern mit variabler Zuweisung

# %%
df2 = df

# %%
df2.loc[0, 'Name'] = 'New Name'

# %%
df2.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                                      New Name    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Cabin Embarked
# 0   330911   7.8292   NaN        Q
# 1   363272   7.0000   NaN        S
# 2   240276   9.6875   NaN        Q
# 3   315154   8.6625   NaN        S
# 4  3101298  12.2875   NaN        S

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                                      New Name    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Cabin Embarked
# 0   330911   7.8292   NaN        Q
# 1   363272   7.0000   NaN        S
# 2   240276   9.6875   NaN        Q
# 3   315154   8.6625   NaN        S
# 4  3101298  12.2875   NaN        S

# %% [markdown]
# Hierbei sieht man sehr schön, dass Änderungen im `df2` direkte Auswirkung auf das original `df` haben, da `df2` lediglich eine Referenz von `df` ist und kein eigenständiges Objekt.

# %% [markdown]
# ### Mit `.copy()`

# %%
df3 = df.copy()

# %%
df3.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                                      New Name    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Cabin Embarked
# 0   330911   7.8292   NaN        Q
# 1   363272   7.0000   NaN        S
# 2   240276   9.6875   NaN        Q
# 3   315154   8.6625   NaN        S
# 4  3101298  12.2875   NaN        S

# %%
df3.loc[1, 'Name'] = 'New Name Again'

# %%
df3.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                                      New Name    male  34.5      0      0
# 1                                New Name Again  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Cabin Embarked
# 0   330911   7.8292   NaN        Q
# 1   363272   7.0000   NaN        S
# 2   240276   9.6875   NaN        Q
# 3   315154   8.6625   NaN        S
# 4  3101298  12.2875   NaN        S

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                                      New Name    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Cabin Embarked
# 0   330911   7.8292   NaN        Q
# 1   363272   7.0000   NaN        S
# 2   240276   9.6875   NaN        Q
# 3   315154   8.6625   NaN        S
# 4  3101298  12.2875   NaN        S

# %% [markdown]
# Erneut wird die Änderung vom `df2` sichtbar, die Änderung die jedoch vom `df3` vorgenommen wurde, wurde auch nur in diesem vorgenommen und ist nicht auf das original `df` übertragen worden.

# %% [markdown]
# ---

# %% [markdown]
# ## `.isin()`

# %% [markdown]
# Der erste Function ist `.isin()`. Mit `.isin()` kannst du Daten auswählen, deren Wert **"in"** einer Liste von Werten ist.

# %% [markdown]
# ![title](./pic/selecting/built_in/2_isin.png)

# %% [markdown]
# Zum Beispiel können wir damit nur Passagiere des Geschlechtes female auswählen:

# %%
df[df.Sex.isin(['female'])]
# Out:
#      PassengerId  Survived  Pclass  \
# 1            893         1       3
# 4            896         1       3
# 6            898         1       3
# 8            900         1       3
# 12           904         1       1
# ..           ...       ...     ...
# 409         1301         1       3
# 410         1302         1       3
# 411         1303         1       1
# 412         1304         1       3
# 414         1306         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 1                   Wilkes, Mrs. James (Ellen Needs)  female  47.0      1
# 4       Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1
# 6                               Connolly, Miss. Kate  female  30.0      0
# 8          Abrahim, Mrs. Joseph (Sophie Halaut Easu)  female  18.0      0
# 12     Snyder, Mrs. John Pillsbury (Nelle Stevenson)  female  23.0      1
# ..                                               ...     ...   ...    ...
# 409                        Peacock, Miss. Treasteall  female   3.0      1
# 410                           Naughton, Miss. Hannah  female   NaN      0
# 411  Minahan, Mrs. William Edward (Lillian E Thorpe)  female  37.0      1
# 412                   Henriksson, Miss. Jenny Lovisa  female  28.0      0
# 414                     Oliva y Ocana, Dona. Fermina  female  39.0      0
#
#      Parch              Ticket      Fare Cabin Embarked
# 1        0              363272    7.0000   NaN        S
# 4        1             3101298   12.2875   NaN        S
# 6        0              330972    7.6292   NaN        Q
# 8        0                2657    7.2292   NaN        C
# 12       0               21228   82.2667   B45        S
# ..     ...                 ...       ...   ...      ...
# 409      1  SOTON/O.Q. 3101315   13.7750   NaN        S
# 410      0              365237    7.7500   NaN        Q
# 411      0               19928   90.0000   C78        Q
# 412      0              347086    7.7750   NaN        S
# 414      0            PC 17758  108.9000  C105        C
#
# [152 rows x 12 columns]

# %% [markdown]
# ...oder alle Passagiere die sich in der Ersten Klasse befinden

# %%
df[df.Pclass.isin([1])]
# Out:
#      PassengerId  Survived  Pclass  \
# 11           903         0       1
# 12           904         1       1
# 14           906         1       1
# 20           912         0       1
# 22           914         1       1
# ..           ...       ...     ...
# 403         1295         0       1
# 404         1296         0       1
# 407         1299         0       1
# 411         1303         1       1
# 414         1306         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 11                          Jones, Mr. Charles Cresson    male  46.0      0
# 12       Snyder, Mrs. John Pillsbury (Nelle Stevenson)  female  23.0      1
# 14   Chaffee, Mrs. Herbert Fuller (Carrie Constance...  female  47.0      1
# 20                              Rothschild, Mr. Martin    male  55.0      1
# 22                Flegenheim, Mrs. Alfred (Antoinette)  female   NaN      0
# ..                                                 ...     ...   ...    ...
# 403                             Carrau, Mr. Jose Pedro    male  17.0      0
# 404                       Frauenthal, Mr. Isaac Gerald    male  43.0      1
# 407                         Widener, Mr. George Dunton    male  50.0      1
# 411    Minahan, Mrs. William Edward (Lillian E Thorpe)  female  37.0      1
# 414                       Oliva y Ocana, Dona. Fermina  female  39.0      0
#
#      Parch       Ticket      Fare Cabin Embarked
# 11       0          694   26.0000   NaN        S
# 12       0        21228   82.2667   B45        S
# 14       0  W.E.P. 5734   61.1750   E31        S
# 20       0     PC 17603   59.4000   NaN        C
# 22       0     PC 17598   31.6833   NaN        S
# ..     ...          ...       ...   ...      ...
# 403      0       113059   47.1000   NaN        S
# 404      0        17765   27.7208   D40        C
# 407      1       113503  211.5000   C80        C
# 411      0        19928   90.0000   C78        Q
# 414      0     PC 17758  108.9000  C105        C
#
# [107 rows x 12 columns]

# %% [markdown]
# Jedoch muss bei `.isin()` immer die komplette Condition angegeben werden, es funktioniert hierbei nicht, für weibliche Passagiere lediglich nach `"f"` zu suchen...

# %%
df[df.Sex.isin(['f'])]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %% [markdown]
# Hierbei bringt die folgende Methode Abhilfe

# %% [markdown]
# ---

# %% [markdown]
# ## `.contains()`

# %% [markdown]
# Anders als bei `.isin()` benötigt `.contains()` nicht die vollständige Condition. Wenn wir z.B. nur den Vornamen der Person wissen, nach der wir suchen wollen, ansonsten jedoch nicht mehr, können wir `.contains()` verwenden. `Pandas` sucht dann nach allen Einträgen im `DataFrame`, die an irgend einer Stelle diesen `String` (oder auch einen einzelnen `Char`) beinhaltet.

# %% [markdown]
# ![title](./pic/selecting/built_in/6_contains.png)

# %%
df.Sex.str.contains('f')
# Out:
# 0      False
# 1       True
# 2      False
# 3      False
# 4       True
#        ...
# 413    False
# 414     True
# 415    False
# 416    False
# 417    False
# Name: Sex, Length: 418, dtype: bool

# %%
df[df.Sex.str.contains('f')]
# Out:
#      PassengerId  Survived  Pclass  \
# 1            893         1       3
# 4            896         1       3
# 6            898         1       3
# 8            900         1       3
# 12           904         1       1
# ..           ...       ...     ...
# 409         1301         1       3
# 410         1302         1       3
# 411         1303         1       1
# 412         1304         1       3
# 414         1306         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 1                   Wilkes, Mrs. James (Ellen Needs)  female  47.0      1
# 4       Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1
# 6                               Connolly, Miss. Kate  female  30.0      0
# 8          Abrahim, Mrs. Joseph (Sophie Halaut Easu)  female  18.0      0
# 12     Snyder, Mrs. John Pillsbury (Nelle Stevenson)  female  23.0      1
# ..                                               ...     ...   ...    ...
# 409                        Peacock, Miss. Treasteall  female   3.0      1
# 410                           Naughton, Miss. Hannah  female   NaN      0
# 411  Minahan, Mrs. William Edward (Lillian E Thorpe)  female  37.0      1
# 412                   Henriksson, Miss. Jenny Lovisa  female  28.0      0
# 414                     Oliva y Ocana, Dona. Fermina  female  39.0      0
#
#      Parch              Ticket      Fare Cabin Embarked
# 1        0              363272    7.0000   NaN        S
# 4        1             3101298   12.2875   NaN        S
# 6        0              330972    7.6292   NaN        Q
# 8        0                2657    7.2292   NaN        C
# 12       0               21228   82.2667   B45        S
# ..     ...                 ...       ...   ...      ...
# 409      1  SOTON/O.Q. 3101315   13.7750   NaN        S
# 410      0              365237    7.7500   NaN        Q
# 411      0               19928   90.0000   C78        Q
# 412      0              347086    7.7750   NaN        S
# 414      0            PC 17758  108.9000  C105        C
#
# [152 rows x 12 columns]

# %%
df.Name.str.contains('an', case=False)
# Out:
# 0      False
# 1      False
# 2       True
# 3      False
# 4       True
#        ...
# 413    False
# 414     True
# 415    False
# 416    False
# 417    False
# Name: Name, Length: 418, dtype: bool

# %%
df[df.Name.str.contains('an', case=False)]
# Out:
#      PassengerId  Survived  Pclass  \
# 2            894         0       2
# 4            896         1       3
# 5            897         0       3
# 7            899         0       2
# 14           906         1       1
# ..           ...       ...     ...
# 397         1289         1       1
# 408         1300         1       3
# 410         1302         1       3
# 411         1303         1       1
# 414         1306         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 2                            Myles, Mr. Thomas Francis    male  62.0      0
# 4         Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1
# 5                           Svensson, Mr. Johan Cervin    male  14.0      0
# 7                         Caldwell, Mr. Albert Francis    male  26.0      1
# 14   Chaffee, Mrs. Herbert Fuller (Carrie Constance...  female  47.0      1
# ..                                                 ...     ...   ...    ...
# 397  Frolicher-Stehli, Mrs. Maxmillian (Margaretha ...  female  48.0      1
# 408                    Riordan, Miss. Johanna Hannah""  female   NaN      0
# 410                             Naughton, Miss. Hannah  female   NaN      0
# 411    Minahan, Mrs. William Edward (Lillian E Thorpe)  female  37.0      1
# 414                       Oliva y Ocana, Dona. Fermina  female  39.0      0
#
#      Parch       Ticket      Fare Cabin Embarked
# 2        0       240276    9.6875   NaN        Q
# 4        1      3101298   12.2875   NaN        S
# 5        0         7538    9.2250   NaN        S
# 7        1       248738   29.0000   NaN        S
# 14       0  W.E.P. 5734   61.1750   E31        S
# ..     ...          ...       ...   ...      ...
# 397      1        13567   79.2000   B41        C
# 408      0       334915    7.7208   NaN        Q
# 410      0       365237    7.7500   NaN        Q
# 411      0        19928   90.0000   C78        Q
# 414      0     PC 17758  108.9000  C105        C
#
# [133 rows x 12 columns]

# %%
# !!
# df[df.Cabin.str.contains('B', case=False)]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-22-2cdf36a99357> in <module>
#       1 # !!
# ----> 2 df[df.Cabin.str.contains('B', case=False)]
#
# /Applications/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    3012
#    3013         # Do we have a (boolean) 1d indexer?
# -> 3014         if com.is_bool_indexer(key):
#    3015             return self._getitem_bool_array(key)
#    3016
#
# /Applications/anaconda3/lib/python3.7/site-packages/pandas/core/common.py in is_bool_indexer(key)
#     112                     # Don't raise on e.g. ["A", "B", np.nan], see
#     113                     #  test_loc_getitem_list_of_labels_categoricalindex_with_na
# --> 114                     raise ValueError(na_msg)
#     115                 return False
#     116             return True
#
# ValueError: Cannot mask with non-boolean array containing NA / NaN values

# %%
df[df.Cabin.str.contains('B', case=False, na=False)]
# Out:
#      PassengerId  Survived  Pclass  \
# 12           904         1       1
# 24           916         1       1
# 26           918         1       1
# 59           951         1       1
# 64           956         0       1
# 92           984         1       1
# 142         1034         0       1
# 166         1058         0       1
# 184         1076         1       1
# 215         1107         0       1
# 287         1179         0       1
# 305         1197         1       1
# 308         1200         0       1
# 316         1208         0       1
# 343         1235         1       1
# 372         1264         0       1
# 390         1282         0       1
# 397         1289         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 12       Snyder, Mrs. John Pillsbury (Nelle Stevenson)  female  23.0      1
# 24     Ryerson, Mrs. Arthur Larned (Emily Maria Borie)  female  48.0      1
# 26                        Ostby, Miss. Helene Ragnhild  female  22.0      0
# 59                         Chaudanson, Miss. Victorine  female  36.0      0
# 64                         Ryerson, Master. John Borie    male  13.0      2
# 92                Davidson, Mrs. Thornton (Orian Hays)  female  27.0      1
# 142                         Ryerson, Mr. Arthur Larned    male  61.0      1
# 166                                 Brandeis, Mr. Emil    male  48.0      0
# 184  Douglas, Mrs. Frederick Charles (Mary Helene B...  female  27.0      1
# 215                              Head, Mr. Christopher    male  42.0      0
# 287                         Snyder, Mr. John Pillsbury    male  24.0      1
# 305  Crosby, Mrs. Edward Gifford (Catherine Elizabe...  female  64.0      1
# 308                         Hays, Mr. Charles Melville    male  55.0      1
# 316                      Spencer, Mr. William Augustus    male  57.0      1
# 343  Cardeza, Mrs. James Warburton Martinez (Charlo...  female  58.0      0
# 372                            Ismay, Mr. Joseph Bruce    male  49.0      0
# 390                         Payne, Mr. Vivian Ponsonby    male  23.0      0
# 397  Frolicher-Stehli, Mrs. Maxmillian (Margaretha ...  female  48.0      1
#
#      Parch      Ticket      Fare            Cabin Embarked
# 12       0       21228   82.2667              B45        S
# 24       3    PC 17608  262.3750  B57 B59 B63 B66        C
# 26       1      113509   61.9792              B36        C
# 59       0    PC 17608  262.3750              B61        C
# 64       2    PC 17608  262.3750  B57 B59 B63 B66        C
# 92       2  F.C. 12750   52.0000              B71        S
# 142      3    PC 17608  262.3750  B57 B59 B63 B66        C
# 166      0    PC 17591   50.4958              B10        C
# 184      1    PC 17558  247.5208          B58 B60        C
# 215      0      113038   42.5000              B11        S
# 287      0       21228   82.2667              B45        S
# 305      1      112901   26.5500              B26        S
# 308      1       12749   93.5000              B69        S
# 316      0    PC 17569  146.5208              B78        C
# 343      1    PC 17755  512.3292      B51 B53 B55        C
# 372      0      112058    0.0000      B52 B54 B56        S
# 390      0       12749   93.5000              B24        S
# 397      1       13567   79.2000              B41        C

# %% [markdown]
# ---

# %% [markdown]
# ## `.notnull()`

# %% [markdown]
# Die zweite ist `.notnull()`. Mit diesen Methoden kannst du Werte hervorheben, nicht leer sind (`NaN`).

# %% [markdown]
# ![title](./pic/selecting/built_in/3_notnull.png)

# %% [markdown]
# `.notnull()` kannst du entweder auf das **komplette** `DataFrame` anwenden und kriegst alle Zeilen, die keinen einzigen `Nan` Value in keiner einzigen Spalte beinhalten...

# %%
df.notnull()
# Out:
#      PassengerId  Survived  Pclass  Name   Sex    Age  SibSp  Parch  Ticket  \
# 0           True      True    True  True  True   True   True   True    True
# 1           True      True    True  True  True  False   True   True    True
# 2           True      True    True  True  True   True   True   True    True
# 3           True      True    True  True  True  False   True   True    True
# 4           True      True    True  True  True   True   True   True    True
# ..           ...       ...     ...   ...   ...    ...    ...    ...     ...
# 418         True      True    True  True  True   True   True   True    True
# 419         True      True    True  True  True   True   True   True    True
# 420         True      True    True  True  True  False   True   True    True
# 421         True      True    True  True  True   True   True   True    True
# 422         True      True    True  True  True   True   True   True    True
#
#      Fare  Cabin  Embarked
# 0    True   True      True
# 1    True  False      True
# 2    True   True      True
# 3    True  False      True
# 4    True  False      True
# ..    ...    ...       ...
# 418  True  False      True
# 419  True  False      True
# 420  True  False      True
# 421  True  False      True
# 422  True  False      True
#
# [423 rows x 12 columns]

# %%
df[df.notnull()]
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ..                                            ...     ...   ...    ...    ...
# 413                            Spector, Mr. Woolf    male   NaN      0      0
# 414                  Oliva y Ocana, Dona. Fermina  female  39.0      0      0
# 415                  Saether, Mr. Simon Sivertsen    male  38.5      0      0
# 416                           Ware, Mr. Frederick    male   NaN      0      0
# 417                      Peter, Master. Michael J    male   NaN      1      1
#
#                  Ticket      Fare Cabin Embarked
# 0                330911    7.8292   NaN        Q
# 1                363272    7.0000   NaN        S
# 2                240276    9.6875   NaN        Q
# 3                315154    8.6625   NaN        S
# 4               3101298   12.2875   NaN        S
# ..                  ...       ...   ...      ...
# 413           A.5. 3236    8.0500   NaN        S
# 414            PC 17758  108.9000  C105        C
# 415  SOTON/O.Q. 3101262    7.2500   NaN        S
# 416              359309    8.0500   NaN        S
# 417                2668   22.3583   NaN        C
#
# [418 rows x 12 columns]

# %% [markdown]
# ...oder aber auch auf **vereinzelte Spalten**, wobei sich dann in anderen Spalten der Zeile wiederrum `Nan` Values befinden können.

# %%
df.loc[df.Cabin.notnull()]
# Out:
#      PassengerId  Survived  Pclass  \
# 12           904         1       1
# 14           906         1       1
# 24           916         1       1
# 26           918         1       1
# 28           920         0       1
# ..           ...       ...     ...
# 404         1296         0       1
# 405         1297         0       2
# 407         1299         0       1
# 411         1303         1       1
# 414         1306         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 12       Snyder, Mrs. John Pillsbury (Nelle Stevenson)  female  23.0      1
# 14   Chaffee, Mrs. Herbert Fuller (Carrie Constance...  female  47.0      1
# 24     Ryerson, Mrs. Arthur Larned (Emily Maria Borie)  female  48.0      1
# 26                        Ostby, Miss. Helene Ragnhild  female  22.0      0
# 28                             Brady, Mr. John Bertram    male  41.0      0
# ..                                                 ...     ...   ...    ...
# 404                       Frauenthal, Mr. Isaac Gerald    male  43.0      1
# 405       Nourney, Mr. Alfred (Baron von Drachstedt")"    male  20.0      0
# 407                         Widener, Mr. George Dunton    male  50.0      1
# 411    Minahan, Mrs. William Edward (Lillian E Thorpe)  female  37.0      1
# 414                       Oliva y Ocana, Dona. Fermina  female  39.0      0
#
#      Parch         Ticket      Fare            Cabin Embarked
# 12       0          21228   82.2667              B45        S
# 14       0    W.E.P. 5734   61.1750              E31        S
# 24       3       PC 17608  262.3750  B57 B59 B63 B66        C
# 26       1         113509   61.9792              B36        C
# 28       0         113054   30.5000              A21        S
# ..     ...            ...       ...              ...      ...
# 404      0          17765   27.7208              D40        C
# 405      0  SC/PARIS 2166   13.8625              D38        C
# 407      1         113503  211.5000              C80        C
# 411      0          19928   90.0000              C78        Q
# 414      0       PC 17758  108.9000             C105        C
#
# [91 rows x 12 columns]

# %% [markdown]
# ---

# %% [markdown]
# ## `.isnull()` / `.isna()`

# %% [markdown]
# Die beiden Methoden `isnull` und `.isna()` geben dir die Zeilen deines `DataFrames` zurück, die `Nan` Values enthalten. Mit diesen Methoden kannst du Werte hervorheben, die leer sind (`NaN`).

# %% [markdown]
# ![title](./pic/selecting/built_in/4_isnull.png)

# %% [markdown]
# Um zum Beispiel Passagiere herauszufilter, deren Alter nicht angegeben ist, würden wir wie folgt vorgehen:

# %% [markdown]
# Zuerst kann das ganze `DataFrame` abgefragt werden und man erhält einen (nicht ganz so übersichtliche) Überblick über alle Zeilen und alle Spalten und ob sich in der jeweiligen Zelle ein `Nan` Value befindet oder nicht

# %%
df.isnull()
# Out:
#      PassengerId  Survived  Pclass   Name    Sex    Age  SibSp  Parch  Ticket  \
# 0          False     False   False  False  False  False  False  False   False
# 1          False     False   False  False  False   True  False  False   False
# 2          False     False   False  False  False  False  False  False   False
# 3          False     False   False  False  False   True  False  False   False
# 4          False     False   False  False  False  False  False  False   False
# ..           ...       ...     ...    ...    ...    ...    ...    ...     ...
# 418        False     False   False  False  False  False  False  False   False
# 419        False     False   False  False  False  False  False  False   False
# 420        False     False   False  False  False   True  False  False   False
# 421        False     False   False  False  False  False  False  False   False
# 422        False     False   False  False  False  False  False  False   False
#
#       Fare  Cabin  Embarked
# 0    False  False     False
# 1    False   True     False
# 2    False  False     False
# 3    False   True     False
# 4    False   True     False
# ..     ...    ...       ...
# 418  False   True     False
# 419  False   True     False
# 420  False   True     False
# 421  False   True     False
# 422  False   True     False
#
# [423 rows x 12 columns]

# %% [markdown]
# Danach kann man sich die spezielle Spalte ansehen, die einen interessert:

# %%
df.Age.isnull()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 413     True
# 414    False
# 415    False
# 416     True
# 417     True
# Name: Age, Length: 418, dtype: bool

# %% [markdown]
# Diese Abfrage können wir in `[]` packen, um die jeweiligen Zeilen des `DataFrames` zu erhalten

# %%
df_age_na = df[df.Age.isnull()]
df_age_na
# Out:
#      PassengerId  Survived  Pclass  \
# 10           902         0       3
# 22           914         1       1
# 29           921         0       3
# 33           925         1       3
# 36           928         1       3
# ..           ...       ...     ...
# 408         1300         1       3
# 410         1302         1       3
# 413         1305         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                                   Name     Sex  Age  SibSp  \
# 10                                    Ilieff, Mr. Ylio    male  NaN      0
# 22                Flegenheim, Mrs. Alfred (Antoinette)  female  NaN      0
# 29                                   Samaan, Mr. Elias    male  NaN      2
# 33   Johnston, Mrs. Andrew G (Elizabeth Lily" Watson)"  female  NaN      1
# 36                                 Roth, Miss. Sarah A  female  NaN      0
# ..                                                 ...     ...  ...    ...
# 408                    Riordan, Miss. Johanna Hannah""  female  NaN      0
# 410                             Naughton, Miss. Hannah  female  NaN      0
# 413                                 Spector, Mr. Woolf    male  NaN      0
# 416                                Ware, Mr. Frederick    male  NaN      0
# 417                           Peter, Master. Michael J    male  NaN      1
#
#      Parch      Ticket     Fare Cabin Embarked
# 10       0      349220   7.8958   NaN        S
# 22       0    PC 17598  31.6833   NaN        S
# 29       0        2662  21.6792   NaN        C
# 33       2  W./C. 6607  23.4500   NaN        S
# 36       0      342712   8.0500   NaN        S
# ..     ...         ...      ...   ...      ...
# 408      0      334915   7.7208   NaN        Q
# 410      0      365237   7.7500   NaN        Q
# 413      0   A.5. 3236   8.0500   NaN        S
# 416      0      359309   8.0500   NaN        S
# 417      1        2668  22.3583   NaN        C
#
# [86 rows x 12 columns]

# %% [markdown]
# Wenn dich speziell der Index interessiert, wo in welchem Fall ein `Nan` Value zu finden ist, kannst du den `.index` Operator an dein `DataFrame` anfügen, und dir werden alle Indexe zurück gegeben, die sich in dem `DataFrame` befinden

# %%
df_age_na.index
# Out:
# Int64Index([ 10,  22,  29,  33,  36,  39,  41,  47,  54,  58,  65,  76,  83,
#              84,  85,  88,  91,  93, 102, 107, 108, 111, 116, 121, 124, 127,
#             132, 133, 146, 148, 151, 160, 163, 168, 170, 173, 183, 188, 191,
#             199, 200, 205, 211, 216, 219, 225, 227, 233, 243, 244, 249, 255,
#             256, 265, 266, 267, 268, 271, 273, 274, 282, 286, 288, 289, 290,
#             292, 297, 301, 304, 312, 332, 339, 342, 344, 357, 358, 365, 366,
#             380, 382, 384, 408, 410, 413, 416, 417],
#            dtype='int64')

# %%
df_age_na.index[0]
# Out:
# 10

# %%
df_age_na.index[1]
# Out:
# 22

# %% [markdown]
# ***

# %%
df.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %% [markdown]
# Dabei spielt es überhaupt keine Rolle, welche der beiden Funktionen du verwendest. Bei Recherchen bin ich auf den Pandas Code gestoßen ([Official Pandas Code auf Github](https://github.com/pandas-dev/pandas/blob/0409521665bd436a10aea7e06336066bf07ff057/pandas/core/dtypes/missing.py#L109)) wo eindeutig hinterlegt ist, dass `.isnull()` eine Referenz auf `.isna()` darstellt. Daher kannst du frei zwischen einen der beiden wählen.

# %% [markdown]
# ![title](./pic/selecting/built_in/7_isna_isnull.png)

# %% [markdown]
# ---

# %% [markdown]
# ## `.duplicated()`

# %% [markdown]
# Diese Methode macht genau das, nachdem sie sich anhört: sie gibt dir Duplikate zurück. Ist also ein Passagier versehentlich zwei mal eingetragen worden, kann dieser die Statistik verfälschen. Solche Duplikate will man direkt zu Beginn sämtlicher analysen erkennen und eliminieren.

# %% [markdown]
# ### Vorbereitung: Duplikate einbauen

# %%
for i in range(0, 5):
    random_index = random.randint(0, len(df))
    print(random_index, df.loc[random_index, 'PassengerId'])
    
    df = df.append(df.loc[random_index])
# Out:
# 367 1259
# 42 934
# 299 1191
# 255 1147
# 117 1009

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 367         1259         1       3
# 42           934         0       3
# 299         1191         0       3
# 255         1147         0       3
# 117         1009         1       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ..                                            ...     ...   ...    ...    ...
# 367  Riihivouri, Miss. Susanna Juhantytar Sanni""  female  22.0      0      0
# 42                          Goldsmith, Mr. Nathan    male  41.0      0      0
# 299                           Johansson, Mr. Nils    male  29.0      0      0
# 255                    MacKay, Mr. George William    male   NaN      0      0
# 117               Sandstrom, Miss. Beatrice Irene  female   1.0      1      1
#
#                  Ticket     Fare Cabin Embarked
# 0                330911   7.8292   NaN        Q
# 1                363272   7.0000   NaN        S
# 2                240276   9.6875   NaN        Q
# 3                315154   8.6625   NaN        S
# 4               3101298  12.2875   NaN        S
# ..                  ...      ...   ...      ...
# 367             3101295  39.6875   NaN        S
# 42   SOTON/O.Q. 3101263   7.8500   NaN        S
# 299              347467   7.8542   NaN        S
# 255          C.A. 42795   7.5500   NaN        S
# 117             PP 9549  16.7000    G6        S
#
# [423 rows x 12 columns]

# %%
df = df.sample(frac=1).reset_index(drop=True)
df
# Out:
#      PassengerId  Survived  Pclass                                       Name  \
# 0            918         1       1               Ostby, Miss. Helene Ragnhild
# 1           1024         1       3              Lefebre, Mrs. Frank (Frances)
# 2            956         0       1                Ryerson, Master. John Borie
# 3           1136         0       3  Johnston, Master. William Arthur Willie""
# 4           1252         0       3                Sage, Master. William Henry
# ..           ...       ...     ...                                        ...
# 418         1172         1       3                     Oreskovic, Miss. Jelka
# 419         1095         1       2                 Quick, Miss. Winifred Vera
# 420         1274         1       3                 Risien, Mrs. Samuel (Emma)
# 421         1161         0       3                          Pokrnic, Mr. Mate
# 422         1281         0       3                Palsson, Master. Paul Folke
#
#         Sex   Age  SibSp  Parch      Ticket      Fare            Cabin  \
# 0    female  22.0      0      1      113509   61.9792              B36
# 1    female   NaN      0      4        4133   25.4667              NaN
# 2      male  13.0      2      2    PC 17608  262.3750  B57 B59 B63 B66
# 3      male   NaN      1      2  W./C. 6607   23.4500              NaN
# 4      male  14.5      8      2    CA. 2343   69.5500              NaN
# ..      ...   ...    ...    ...         ...       ...              ...
# 418  female  23.0      0      0      315085    8.6625              NaN
# 419  female   8.0      1      1       26360   26.0000              NaN
# 420  female   NaN      0      0      364498   14.5000              NaN
# 421    male  17.0      0      0      315095    8.6625              NaN
# 422    male   6.0      3      1      349909   21.0750              NaN
#
#     Embarked
# 0          C
# 1          S
# 2          C
# 3          S
# 4          S
# ..       ...
# 418        S
# 419        S
# 420        S
# 421        S
# 422        S
#
# [423 rows x 12 columns]

# %% [markdown]
# ![title](./pic/selecting/built_in/5_duplicated.png)

# %%
df_duplicates = df[df.duplicated()]
df_duplicates
# Out:
#      PassengerId  Survived  Pclass  \
# 169         1259         1       3
# 184         1191         0       3
# 185         1147         0       3
# 237         1009         1       3
# 347          934         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 169  Riihivouri, Miss. Susanna Juhantytar Sanni""  female  22.0      0      0
# 184                           Johansson, Mr. Nils    male  29.0      0      0
# 185                    MacKay, Mr. George William    male   NaN      0      0
# 237               Sandstrom, Miss. Beatrice Irene  female   1.0      1      1
# 347                         Goldsmith, Mr. Nathan    male  41.0      0      0
#
#                  Ticket     Fare Cabin Embarked
# 169             3101295  39.6875   NaN        S
# 184              347467   7.8542   NaN        S
# 185          C.A. 42795   7.5500   NaN        S
# 237             PP 9549  16.7000    G6        S
# 347  SOTON/O.Q. 3101263   7.8500   NaN        S

# %%
df.loc[134, 'Name'] = 'Neuer Name'
df
# Out:
#      PassengerId  Survived  Pclass                                       Name  \
# 0            918         1       1               Ostby, Miss. Helene Ragnhild
# 1           1024         1       3              Lefebre, Mrs. Frank (Frances)
# 2            956         0       1                Ryerson, Master. John Borie
# 3           1136         0       3  Johnston, Master. William Arthur Willie""
# 4           1252         0       3                Sage, Master. William Henry
# ..           ...       ...     ...                                        ...
# 418         1172         1       3                     Oreskovic, Miss. Jelka
# 419         1095         1       2                 Quick, Miss. Winifred Vera
# 420         1274         1       3                 Risien, Mrs. Samuel (Emma)
# 421         1161         0       3                          Pokrnic, Mr. Mate
# 422         1281         0       3                Palsson, Master. Paul Folke
#
#         Sex   Age  SibSp  Parch      Ticket      Fare            Cabin  \
# 0    female  22.0      0      1      113509   61.9792              B36
# 1    female   NaN      0      4        4133   25.4667              NaN
# 2      male  13.0      2      2    PC 17608  262.3750  B57 B59 B63 B66
# 3      male   NaN      1      2  W./C. 6607   23.4500              NaN
# 4      male  14.5      8      2    CA. 2343   69.5500              NaN
# ..      ...   ...    ...    ...         ...       ...              ...
# 418  female  23.0      0      0      315085    8.6625              NaN
# 419  female   8.0      1      1       26360   26.0000              NaN
# 420  female   NaN      0      0      364498   14.5000              NaN
# 421    male  17.0      0      0      315095    8.6625              NaN
# 422    male   6.0      3      1      349909   21.0750              NaN
#
#     Embarked
# 0          C
# 1          S
# 2          C
# 3          S
# 4          S
# ..       ...
# 418        S
# 419        S
# 420        S
# 421        S
# 422        S
#
# [423 rows x 12 columns]

# %%
df_duplicates = df[df.duplicated()]
df_duplicates
# Out:
#      PassengerId  Survived  Pclass  \
# 169         1259         1       3
# 184         1191         0       3
# 185         1147         0       3
# 237         1009         1       3
# 347          934         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 169  Riihivouri, Miss. Susanna Juhantytar Sanni""  female  22.0      0      0
# 184                           Johansson, Mr. Nils    male  29.0      0      0
# 185                    MacKay, Mr. George William    male   NaN      0      0
# 237               Sandstrom, Miss. Beatrice Irene  female   1.0      1      1
# 347                         Goldsmith, Mr. Nathan    male  41.0      0      0
#
#                  Ticket     Fare Cabin Embarked
# 169             3101295  39.6875   NaN        S
# 184              347467   7.8542   NaN        S
# 185          C.A. 42795   7.5500   NaN        S
# 237             PP 9549  16.7000    G6        S
# 347  SOTON/O.Q. 3101263   7.8500   NaN        S

# %% [markdown]
# <br>
#
# Mit dem Attribut `subset=` kann die Duplikatssuche auf eine oder mehrere Spalten beschränkt werden. Dadurch wird nicht die ganze Zeile mit jeder weiteren Zeile verglichen, sondern lediglich die jeweilige Spalte der Zeile mit der Spalte der anderen Zeilen. Somit kann verfeinert nach Duplikaten gesucht und präziser abgefragt werden.

# %%
df_duplicates_col = df[df.duplicated(subset='PassengerId')]
df_duplicates_col
# Out:
#      PassengerId  Survived  Pclass  \
# 169         1259         1       3
# 184         1191         0       3
# 185         1147         0       3
# 237         1009         1       3
# 347          934         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 169  Riihivouri, Miss. Susanna Juhantytar Sanni""  female  22.0      0      0
# 184                           Johansson, Mr. Nils    male  29.0      0      0
# 185                    MacKay, Mr. George William    male   NaN      0      0
# 237               Sandstrom, Miss. Beatrice Irene  female   1.0      1      1
# 347                         Goldsmith, Mr. Nathan    male  41.0      0      0
#
#                  Ticket     Fare Cabin Embarked
# 169             3101295  39.6875   NaN        S
# 184              347467   7.8542   NaN        S
# 185          C.A. 42795   7.5500   NaN        S
# 237             PP 9549  16.7000    G6        S
# 347  SOTON/O.Q. 3101263   7.8500   NaN        S

# %% [markdown]
# Wie du diese Duplikate anschließend erfolgreich löschen kannst, behandeln wir zu einem späteren Zeitpunkt, da es thematisch nicht zu diesem Notebook passt.
