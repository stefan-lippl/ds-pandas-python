# %% [markdown]
# #  <center> <u>Übung:</u> Pandas Data Types & Missing Values

# %% [markdown]
# ### 1) (L) Importiere `Pandas` und lade den Datensatz von `uebung/cars.csv` und lass dir den `Kopf` ausgeben

# %%
import pandas as pd
pd.set_option('display.max_columns', None)

# %%
df = pd.read_csv('./uebung/cars.csv', index_col=0)
df.drop(['Unnamed: 23'], axis=1, inplace=True)
df.head()
# Out:
#            marke   modell     preis   kilometer erstzulassung  \
# 0     Volkswagen     Golf   9.797 €   79.449 km       04/2011
# 1     Volkswagen     Golf  13.890 €   76.486 km       01/2015
# 2  Mercedes-Benz  SLK 300  19.990 €   84.000 km       07/2009
# 3  Mercedes-Benz  SLK 350  19.990 €   84.000 km       07/2009
# 4  Mercedes-Benz    A 220  17.450 €  109.252 km       12/2012
#
#           kraftstoffart        getriebe         leistung    hubraum       hu  \
# 0                Benzin  Schaltgetriebe    63 kW (86 PS)  1.197 cm³      Neu
# 1  Benzin, E10-geeignet  Schaltgetriebe   92 kW (125 PS)  1.395 cm³      Neu
# 2                Benzin       Automatik  170 kW (231 PS)  2.997 cm³  08/2023
# 3                Benzin       Automatik  170 kW (231 PS)  2.997 cm³  08/2023
# 4                Diesel       Automatik  125 kW (170 PS)  2.143 cm³      Neu
#
#        plz             farbe  anzahlderFahrzeughalter          kategorie  \
# ...

# %% [markdown]
# ***

# %% [markdown]
# ### 2) (L) Lasse dir die Datentypen sämtlicher Spalten ausgeben

# %%
df.dtypes
# Out:
# marke                       object
# modell                      object
# preis                       object
# kilometer                   object
# erstzulassung               object
# kraftstoffart               object
# getriebe                    object
# leistung                    object
# hubraum                     object
# hu                          object
# plz                        float64
# farbe                       object
# anzahlderFahrzeughalter    float64
# kategorie                   object
# anzahlSitzplaetze          float64
# anzahlderTueren             object
# schadstoffklasse            object
# umweltplakette              object
# klimatisierung              object
# einparkhilfe                object
# airbags                     object
# innenausstattung            object
# ausstattung                 object
# dtype: object

# %% [markdown]
# ***

# %% [markdown]
# ### 3) (L) Lasse dir den Datentyp der Spalte `preis` des ersten Eintrags deines `DataFrames` ausgeben

# %%
type(df.loc[0, 'preis'])
# Out:
# str

# %% [markdown]
# ***

# %% [markdown]
# ### 4) (L) In welchen Zeilen befindet sich ein `Nan` Value in der Spalte `kilometer`?

# %%
df[pd.isnull(df.kilometer)]
# Out:
#               marke modell preis kilometer erstzulassung kraftstoffart  \
# 10              NaN    NaN   NaN       NaN           NaN           NaN
# 75    Mercedes-Benz  A 180   NaN       NaN           NaN           NaN
# 87              NaN    NaN   NaN       NaN           NaN           NaN
# 90              NaN    NaN   NaN       NaN           NaN           NaN
# 117             NaN    NaN   NaN       NaN           NaN           NaN
# ...             ...    ...   ...       ...           ...           ...
# 9902            NaN    NaN   NaN       NaN           NaN           NaN
# 9923            NaN    NaN   NaN       NaN           NaN           NaN
# 9944            NaN    NaN   NaN       NaN           NaN           NaN
# 9965            NaN    NaN   NaN       NaN           NaN           NaN
# 9986            NaN    NaN   NaN       NaN           NaN           NaN
#
#      getriebe leistung hubraum   hu      plz farbe  anzahlderFahrzeughalter  \
# ...

# %% [markdown]
# ***

# %% [markdown]
# ### 5) (M) Wieviele Autos bleiben übrig, wenn du alle Zeilen löscht, bei denen sich in der Spalte `preis` ein `Nan` Value befindet?

# %%
df = df.dropna(subset=['preis'])
df.shape
# Out:
# (9523, 23)

# %% [markdown]
# ***

# %% [markdown]
# ### 6) (M) Fülle alle `Nan` Values in der Spalte `kilometer` mit dem String `Unknown` und prüfe anschleißend ob sich immer noch `Nan` Values in der Spalte `kilometer` befinden

# %%
df['kilometer'] = df.kilometer.fillna("Unknown")

# %%
df[df.kilometer.isna()]
# Out:
# Empty DataFrame
# Columns: [marke, modell, preis, kilometer, erstzulassung, kraftstoffart, getriebe, leistung, hubraum, hu, plz, farbe, anzahlderFahrzeughalter, kategorie, anzahlSitzplaetze, anzahlderTueren, schadstoffklasse, umweltplakette, klimatisierung, einparkhilfe, airbags, innenausstattung, ausstattung]
# Index: []

# %%
df.kilometer.isna().unique()
# Out:
# array([False])
