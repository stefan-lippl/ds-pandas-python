# %% [markdown]
# ![title](./pic/zuweisen/neue_spalte/1_title.png)

# %%
import pandas as pd

# %%
df = pd.read_csv('./csv/titanic.csv')
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Cabin Embarked
# 0   330911   7.8292   NaN        Q
# 1   363272   7.0000   NaN        S
# 2   240276   9.6875   NaN        Q
# 3   315154   8.6625   NaN        S
# 4  3101298  12.2875   NaN        S

# %% [markdown]
# ---

# %% [markdown]
# ## Daten zuweisen: Komplette Spalte

# %% [markdown]
# Es ist sehr einfach, einem `DataFrame` Daten zuzuweisen. Du kannst entweder einen konstanten Wert zuweisen oder Daten anhand von anderen Featureeigenschaften generieren.

# %% [markdown]
# ![title](./pic/zuweisen/neue_spalte/2_ganze_spalte.png)

# %%
df['herkunft'] = 'somewhere'
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ..                                            ...     ...   ...    ...    ...
# 413                            Spector, Mr. Woolf    male   NaN      0      0
# 414                  Oliva y Ocana, Dona. Fermina  female  39.0      0      0
# 415                  Saether, Mr. Simon Sivertsen    male  38.5      0      0
# 416                           Ware, Mr. Frederick    male   NaN      0      0
# 417                      Peter, Master. Michael J    male   NaN      1      1
#
#                  Ticket      Fare Cabin Embarked   herkunft
# 0                330911    7.8292   NaN        Q  somewhere
# 1                363272    7.0000   NaN        S  somewhere
# 2                240276    9.6875   NaN        Q  somewhere
# 3                315154    8.6625   NaN        S  somewhere
# 4               3101298   12.2875   NaN        S  somewhere
# ..                  ...       ...   ...      ...        ...
# 413           A.5. 3236    8.0500   NaN        S  somewhere
# 414            PC 17758  108.9000  C105        C  somewhere
# 415  SOTON/O.Q. 3101262    7.2500   NaN        S  somewhere
# 416              359309    8.0500   NaN        S  somewhere
# 417                2668   22.3583   NaN        C  somewhere
#
# [418 rows x 13 columns]

# %% [markdown]
# ---

# %% [markdown]
# ## Daten zuweisen: Spezielle Spalte in spezieller Zeile

# %% [markdown]
# Oder mit einem speziellen Wert an einer speziellen Stelle:
#
# Denn, mit `.loc` kann man nicht nur die Daten eines `DataFrames` abfragen, sondern auch neue Daten hinzufügen.

# %% [markdown]
# ![title](./pic/zuweisen/neue_spalte/3_spezieller_wert.png)

# %%
df.loc[3, 'herkunft'] = 'Deutschland'
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Cabin Embarked     herkunft
# 0   330911   7.8292   NaN        Q  Deutschland
# 1   363272   7.0000   NaN        S    somewhere
# 2   240276   9.6875   NaN        Q    somewhere
# 3   315154   8.6625   NaN        S    somewhere
# 4  3101298  12.2875   NaN        S    somewhere

# %% [markdown]
# ---

# %% [markdown]
# ## Bedingte Zuweisung aufgrund Featureeigenschaften

# %% [markdown]
# Ebenso können Werte einer Spalte aufgrundlage einer anderen Spalte zugewiesen werden. Nachfolgend teilen wir das Alter jedes einzelnen Passagieres in Altersgruppen (Kleinkind, Kind, Erwachsen) ein. In diesem Fall machen wir das mit einer einfachen `for`-Schleife (die für größere Datensätze nicht empfehlenswert ist) um das Beispiel so einfach wie möglich zu halten. Zu einem späteren Zeitpunkt wirst du **advanced functions** von `Pandas` kennenlernen, mit deren Hilfe du `for`-Schleifen vermeiden und somit die Performance verbessern kannst.

# %%
for i in range(0, len(df)):
    curr_age = df.loc[i, 'Age']
    
    if curr_age < 3:
        df.loc[i, 'Gruppe'] = 'Kleinkind'
    if curr_age >= 3 and curr_age <= 17:
        df.loc[i, 'Gruppe'] = 'Kind'
    if curr_age > 17:
        df.loc[i, 'Gruppe'] = 'Erwachsen'

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ..                                            ...     ...   ...    ...    ...
# 413                            Spector, Mr. Woolf    male   NaN      0      0
# 414                  Oliva y Ocana, Dona. Fermina  female  39.0      0      0
# 415                  Saether, Mr. Simon Sivertsen    male  38.5      0      0
# 416                           Ware, Mr. Frederick    male   NaN      0      0
# 417                      Peter, Master. Michael J    male   NaN      1      1
#
#                  Ticket      Fare Cabin Embarked     herkunft     Gruppe
# 0                330911    7.8292   NaN        Q  Deutschland  Erwachsen
# 1                363272    7.0000   NaN        S    somewhere  Erwachsen
# 2                240276    9.6875   NaN        Q    somewhere  Erwachsen
# 3                315154    8.6625   NaN        S    somewhere  Erwachsen
# 4               3101298   12.2875   NaN        S    somewhere  Erwachsen
# ..                  ...       ...   ...      ...          ...        ...
# 413           A.5. 3236    8.0500   NaN        S    somewhere  Erwachsen
# 414            PC 17758  108.9000  C105        C    somewhere  Erwachsen
# 415  SOTON/O.Q. 3101262    7.2500   NaN        S    somewhere  Erwachsen
# 416              359309    8.0500   NaN        S    somewhere  Erwachsen
# 417                2668   22.3583   NaN        C    somewhere  Erwachsen
#
# [418 rows x 14 columns]

# %%
df[df.Gruppe == 'Kleinkind']
# Out:
#      PassengerId  Survived  Pclass                                     Name  \
# 89           981         0       2              Wells, Master. Ralph Lester
# 117         1009         1       3          Sandstrom, Miss. Beatrice Irene
# 201         1093         0       3  Danbom, Master. Gilbert Sigvard Emanuel
# 250         1142         1       2                    West, Miss. Barbara J
# 263         1155         1       3             Klasen, Miss. Gertrud Emilia
# 281         1173         0       3           Peacock, Master. Alfred Edward
# 284         1176         1       3              Rosblom, Miss. Salli Helena
# 296         1188         1       2                    Laroche, Miss. Louise
# 307         1199         0       3                Aks, Master. Philip Frank
# 354         1246         1       3  Dean, Miss. Elizabeth Gladys Millvina""
#
#         Sex   Age  SibSp  Parch              Ticket     Fare Cabin Embarked  \
# 89     male  2.00      1      1               29103  23.0000   NaN        S
# 117  female  1.00      1      1             PP 9549  16.7000    G6        S
# 201    male  0.33      0      2              347080  14.4000   NaN        S
# 250  female  0.92      1      2          C.A. 34651  27.7500   NaN        S
# 263  female  1.00      1      1              350405  12.1833   NaN        S
# 281    male  0.75      1      1  SOTON/O.Q. 3101315  13.7750   NaN        S
# 284  female  2.00      1      1              370129  20.2125   NaN        S
# 296  female  1.00      1      2       SC/Paris 2123  41.5792   NaN        C
# 307    male  0.83      0      1              392091   9.3500   NaN        S
# 354  female  0.17      1      2           C.A. 2315  20.5750   NaN        S
#
#       herkunft     Gruppe
# 89   somewhere  Kleinkind
# 117  somewhere  Kleinkind
# 201  somewhere  Kleinkind
# 250  somewhere  Kleinkind
# 263  somewhere  Kleinkind
# 281  somewhere  Kleinkind
# 284  somewhere  Kleinkind
# 296  somewhere  Kleinkind
# 307  somewhere  Kleinkind
# 354  somewhere  Kleinkind
